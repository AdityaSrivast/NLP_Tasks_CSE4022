# %%
#Task 3 COUNT VECTORIZER
from sklearn.feature_extraction.text import CountVectorizer

# %%
vect = CountVectorizer(binary=True)

# %%
## import text from doc
import textract
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-2bf757dae3db> in <module>
#       1 ## import text from doc
# ----> 2 import textract
#
# ModuleNotFoundError: No module named 'textract'

# %%
# !pip install textract
# Out:
# Collecting textract
#   Downloading textract-1.6.3-py3-none-any.whl (21 kB)
# Collecting extract-msg==0.23.1
#   Downloading extract_msg-0.23.1-py2.py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 30 kB/s  eta 0:00:01
# Collecting SpeechRecognition==3.8.1
#   Downloading SpeechRecognition-3.8.1-py2.py3-none-any.whl (32.8 MB)
#      |████████████████████████████████| 32.8 MB 44 kB/s  eta 0:00:01
# Collecting beautifulsoup4==4.8.0
#   Downloading beautifulsoup4-4.8.0-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 138 kB/s eta 0:00:01
# Collecting python-pptx==0.6.18
#   Downloading python-pptx-0.6.18.tar.gz (8.9 MB)
#      |████████████████████████████████| 8.9 MB 20 kB/s  eta 0:00:01
# Collecting pdfminer.six==20181108
#   Downloading pdfminer.six-20181108-py2.py3-none-any.whl (5.6 MB)
#      |████████████████████████████████| 5.6 MB 145 kB/s eta 0:00:01
# Requirement already satisfied: xlrd==1.2.0 in /home/adityasrivast/anaconda3/lib/python3.7/site-packages (from textract) (1.2.0)
# Collecting docx2txt==0.8
#   Downloading docx2txt-0.8.tar.gz (2.8 kB)
# Collecting EbookLib==0.17.1
#   Downloading EbookLib-0.17.1.tar.gz (111 kB)
#      |████████████████████████████████| 111 kB 778 kB/s eta 0:00:01
# Collecting argcomplete==1.10.0
#   Downloading argcomplete-1.10.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: chardet==3.0.4 in /home/adityasrivast/anaconda3/lib/python3.7/site-packages (from textract) (3.0.4)
# Requirement already satisfied: six==1.12.0 in /home/adityasrivast/anaconda3/lib/python3.7/site-packages (from textract) (1.12.0)
# Collecting tzlocal==1.5.1
#   Downloading tzlocal-1.5.1.tar.gz (16 kB)
# Requirement already satisfied: olefile==0.46 in /home/adityasrivast/anaconda3/lib/python3.7/site-packages (from extract-msg==0.23.1->textract) (0.46)
# Collecting imapclient==2.1.0
#   Downloading IMAPClient-2.1.0-py2.py3-none-any.whl (73 kB)
#      |████████████████████████████████| 73 kB 93 kB/s  eta 0:00:01
# Requirement already satisfied: soupsieve>=1.2 in /home/adityasrivast/anaconda3/lib/python3.7/site-packages (from beautifulsoup4==4.8.0->textract) (1.8)
# Requirement already satisfied: lxml>=3.1.0 in /home/adityasrivast/anaconda3/lib/python3.7/site-packages (from python-pptx==0.6.18->textract) (4.3.4)
# Requirement already satisfied: Pillow>=3.3.2 in /home/adityasrivast/anaconda3/lib/python3.7/site-packages (from python-pptx==0.6.18->textract) (6.1.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /home/adityasrivast/anaconda3/lib/python3.7/site-packages (from python-pptx==0.6.18->textract) (1.1.8)
# Collecting pycryptodome
#   Downloading pycryptodome-3.9.8-cp37-cp37m-manylinux1_x86_64.whl (13.7 MB)
#      |████████████████████████████████| 13.7 MB 284 kB/s eta 0:00:01
# Requirement already satisfied: sortedcontainers in /home/adityasrivast/anaconda3/lib/python3.7/site-packages (from pdfminer.six==20181108->textract) (2.1.0)
# Requirement already satisfied: pytz in /home/adityasrivast/anaconda3/lib/python3.7/site-packages (from tzlocal==1.5.1->extract-msg==0.23.1->textract) (2019.1)
# Building wheels for collected packages: python-pptx, docx2txt, EbookLib, tzlocal
#   Building wheel for python-pptx (setup.py) ... done
#   Created wheel for python-pptx: filename=python_pptx-0.6.18-py3-none-any.whl size=275702 sha256=3212ac1152334e5b7b5317f0798a6bdf45adfd2832a3649146037a6790e61542
#   Stored in directory: /home/adityasrivast/.cache/pip/wheels/68/99/55/8f6d0c128a214c26ac5b9f75ea68f6387feec407055458af1e
#   Building wheel for docx2txt (setup.py) ... done
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3962 sha256=54653d7cdb170077de88a773f0288d4e35a202143030c6f7ea3a412a2f55ad1f
#   Stored in directory: /home/adityasrivast/.cache/pip/wheels/b7/20/b2/473e3aea9a0c0d3e7b2f7bd81d06d0794fec12752733d1f3a8
#   Building wheel for EbookLib (setup.py) ... done
#   Created wheel for EbookLib: filename=EbookLib-0.17.1-py3-none-any.whl size=38163 sha256=2934046cb5ad2c778026f179138ece9a407272507126307bf95e8751064889f1
#   Stored in directory: /home/adityasrivast/.cache/pip/wheels/43/39/fd/db4f652431a55d28472ba7f5f7c9a8efad03b97f443a48ea2f
#   Building wheel for tzlocal (setup.py) ... done
#   Created wheel for tzlocal: filename=tzlocal-1.5.1-py3-none-any.whl size=17542 sha256=1f03de963ac965cbaaa5c27977d2244ba931e3ac44e47f403e97a32ceba7baca
#   Stored in directory: /home/adityasrivast/.cache/pip/wheels/6a/76/b4/f97e26f8f60b5b2b1287415f1202e2b34a97775cead74072be
# Successfully built python-pptx docx2txt EbookLib tzlocal
# Installing collected packages: tzlocal, imapclient, extract-msg, SpeechRecognition, beautifulsoup4, python-pptx, pycryptodome, pdfminer.six, docx2txt, EbookLib, argcomplete, textract
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.7.1
#     Uninstalling beautifulsoup4-4.7.1:
#       Successfully uninstalled beautifulsoup4-4.7.1
# Successfully installed EbookLib-0.17.1 SpeechRecognition-3.8.1 argcomplete-1.10.0 beautifulsoup4-4.8.0 docx2txt-0.8 extract-msg-0.23.1 imapclient-2.1.0 pdfminer.six-20181108 pycryptodome-3.9.8 python-pptx-0.6.18 textract-1.6.3 tzlocal-1.5.1

# %%
import textract
nlpExcerpt=textract.process("nlp.odt")
print(nlpExcerpt)
# Out:
# b'Natural language processing has its roots in the 1950s. Already in 1950, Alan Turing published an article titled "Computing Machinery and Intelligence" which proposed what is now called the Turing test as a criterion of intelligence, a task that involves the automated interpretation and generation of natural language, but at the time not articulated as a problem separate from artificial intelligence. \nSymbolic NLP (1950s - early 1990s)\nThe premise of symbolic NLP is well-summarized by John Searle\'s Chinese room experiment: Given a collection of rules (e.g., a Chinese phrasebook, with questions and matching answers), the computer emulates natural language understanding (or other NLP tasks) by applying those rules to the data it is confronted with. \n1950s: The Georgetown experiment in 1954 involved fully automatic translation of more than sixty Russian sentences into English. The authors claimed that within three or five years, machine translation would be a solved problem.[2] However, real progress was much slower, and after the ALPAC report in 1966, which found that ten-year-long research had failed to fulfill the expectations, funding for machine translation was dramatically reduced. Little further research in machine translation was conducted until the late 1980s when the first statistical machine translation systems were developed. \n1960s: Some notably successful natural language processing systems developed in the 1960s were SHRDLU, a natural language system working in restricted "blocks worlds" with restricted vocabularies, and ELIZA, a simulation of a Rogerian psychotherapist, written by Joseph Weizenbaum between 1964 and 1966. Using almost no information about human thought or emotion, ELIZA sometimes provided a startlingly human-like interaction. When the "patient" exceeded the very small knowledge base, ELIZA might provide a generic response, for example, responding to "My head hurts" with "Why do you say your head hurts?". \n1970s: During the 1970s, many programmers began to write "conceptual ontologies", which structured real-world information into computer-understandable data. Examples are MARGIE (Schank, 1975), SAM (Cullingford, 1978), PAM (Wilensky, 1978), TaleSpin (Meehan, 1976), QUALM (Lehnert, 1977), Politics (Carbonell, 1979), and Plot Units (Lehnert 1981). During this time, the first many chatterbots were written (e.g., PARRY). \n1980s: The 1980s and early 1990s mark the hey-day of symbolic methods in NLP. Focus areas of the time included research on rule-based parsing (e.g., the development of HPSG as a computational operationalization of generative grammar), morphology (e.g., two-level morphology[3]), semantics (e.g., Lesk algorithm), reference (e.g., within Centering Theory[4]) and other areas of natural language understanding (e.g., in the Rhetorical Structure Theory). Other lines of research were continued, e.g., the development of chatterbots with Racter and Jabberwacky. An important development (that eventually led to the statistical turn in the 1990s) was the rising importance of quantitative evaluation in this period.[5]\nStatistical NLP (1990s - 2010s)\nUp to the 1980s, most natural language processing systems were based on complex sets of hand-written rules. Starting in the late 1980s, however, there was a revolution in natural language processing with the introduction of machine learning algorithms for language processing. This was due to both the steady increase in computational power (see Moore\'s law) and the gradual lessening of the dominance of Chomskyan theories of linguistics (e.g. transformational grammar), whose theoretical underpinnings discouraged the sort of corpus linguistics that underlies the machine-learning approach to language processing.[6] \n1990s: Many of the notable early successes on statistical methods in NLP occurred in the field of machine translation, due especially to work at IBM Research. These systems were able to take advantage of existing multilingual textua ...

# %%
aiExcerpt = textract.process("ai.odt")
print(aiExcerpt)
# Out:
# b'Artificial intelligence (AI), sometimes called machine intelligence, is intelligence demonstrated by machines, unlike the natural intelligence displayed by humans and animals. Leading AI textbooks define the field as the study of "intelligent agents": any device that perceives its environment and takes actions that maximize its chance of successfully achieving its goals.[1] Colloquially, the term "artificial intelligence" is often used to describe machines (or computers) that mimic "cognitive" functions that humans associate with the human mind, such as "learning" and "problem solving".[2] \nAs machines become increasingly capable, tasks considered to require "intelligence" are often removed from the definition of AI, a phenomenon known as the AI effect.[3] A quip in Tesler\'s Theorem says "AI is whatever hasn\'t been done yet."[4] For instance, optical character recognition is frequently excluded from things considered to be AI,[5] having become a routine technology.[6] Modern machine capabilities generally classified as AI include successfully understanding human speech,[7] competing at the highest level in strategic game systems (such as chess and Go),[8] autonomously operating cars, intelligent routing in content delivery networks, and military simulations.[9] \nArtificial intelligence was founded as an academic discipline in 1955, and in the years since has experienced several waves of optimism,[10][11] followed by disappointment and the loss of funding (known as an "AI winter"),[12][13] followed by new approaches, success and renewed funding.[11][14] For most of its history, AI research has been divided into sub-fields that often fail to communicate with each other.[15] These sub-fields are based on technical considerations, such as particular goals (e.g. "robotics" or "machine learning"),[16] the use of particular tools ("logic" or artificial neural networks), or deep philosophical differences.[17][18][19] Sub-fields have also been based on social factors (particular institutions or the work of particular researchers).[15] \nThe traditional problems (or goals) of AI research include reasoning, knowledge representation, planning, learning, natural language processing, perception and the ability to move and manipulate objects.[16] General intelligence is among the field\'s long-term goals.[20] Approaches include statistical methods, computational intelligence, and traditional symbolic AI. Many tools are used in AI, including versions of search and mathematical optimization, artificial neural networks, and methods based on statistics, probability and economics. The AI field draws upon computer science, information engineering, mathematics, psychology, linguistics, philosophy, and many other fields. \nThe field was founded on the assumption that human intelligence "can be so precisely described that a machine can be made to simulate it".[21] This raises philosophical arguments about the mind and the ethics of creating artificial beings endowed with human-like intelligence. These issues have been explored by myth, fiction and philosophy since antiquity.[22] Some people also consider AI to be a danger to humanity if it progresses unabated.[23][24] Others believe that AI, unlike previous technological revolutions, will create a risk of mass unemployment.[25] \nIn the twenty-first century, AI techniques have experienced a resurgence following concurrent advances in computer power, large amounts of data, and theoretical understanding; and AI techniques have become an essential part of the technology industry, helping to solve many challenging problems in computer science, software engineering and operations research.\n\nThought-capable artificial beings appeared as storytelling devices in antiquity,[27] and have been common in fiction, as in Mary Shelley\'s Frankenstein or Karel \xc4\x8capek\'s R.U.R. (Rossum\'s Universal Robots).[28] These characters and their fates raised many of the same issues now discussed in the ethics o ...

# %%
x=str(nlpExcerpt)
x=x[2:] #to remove b'
type(x)
# Out:
# str

# %%
text1=x.strip().split()
text1
# Out:
# ['Natural',
#  'language',
#  'processing',
#  'has',
#  'its',
#  'roots',
#  'in',
#  'the',
#  '1950s.',
#  'Already',
#  'in',
#  '1950,',
#  'Alan',
#  'Turing',
#  'published',
#  'an',
#  'article',
#  'titled',
#  '"Computing',
#  'Machinery',
#  'and',
#  'Intelligence"',
#  'which',
#  'proposed',
#  'what',
#  'is',
#  'now',
#  'called',
#  'the',
#  'Turing',
#  'test',
#  'as',
#  'a',
#  'criterion',
#  'of',
#  'intelligence,',
#  'a',
#  'task',
#  'that',
#  'involves',
#  'the',
#  'automated',
#  'interpretation',
#  'and',
#  'generation',
#  'of',
#  'natural',
#  'language,',
#  'but',
#  'at',
#  'the',
#  'time',
#  'not',
#  'articulated',
#  'as',
#  'a',
#  'problem',
#  'separate',
#  'from',
#  'artificial',
#  'intelligence.',
#  '\\nSymbolic',
#  'NLP',
#  '(1950s',
#  '-',
#  'early',
#  '1990s)\\nThe',
#  'premise',
#  'of',
#  'symbolic',
#  'NLP',
#  'is',
#  'well-summarized',
#  'by',
#  'John',
#  "Searle\\'s",
#  'Chinese',
#  'room',
#  'experiment:',
#  'Given',
#  'a',
#  'collection',
#  'of',
#  'rules',
#  '(e.g.,',
#  'a',
#  'Chinese',
#  'phrasebook,',
#  'with',
#  'questions',
#  'and',
#  'matching',
#  'answers),',
#  'the',
#  'computer',
#  'emulates',
#  'natural',
#  'language',
#  'understanding',
#  '(or',
#  'other',
#  'NLP',
#  'tasks)',
#  'by',
#  'applying',
#  'those',
#  'rules',
#  'to',
#  'the',
#  'data',
#  'it',
#  'is',
#  'confronted',
#  'with.',
#  '\\n1950s:',
#  'The',
#  'Georgetown',
#  'experiment',
#  'in',
#  '1954',
#  'involved',
#  'fully',
#  'automatic',
#  'translation',
#  'of',
#  'more',
#  'than',
#  'sixty',
#  'Russian',
#  'sentences',
#  'into',
#  'English.',
#  'The',
#  'authors',
#  'claimed',
#  'that',
#  'within',
#  'three',
#  'or',
#  'five',
#  'years,',
#  'machine',
#  'translation',
#  'would',
#  'be',
#  'a',
#  'solved',
#  'problem.[2]',
#  'However,',
#  'real',
#  'progress',
#  'was',
#  'much',
#  'slower,',
#  'and',
#  'after',
#  'the',
#  'ALPAC',
#  'report',
#  'in',
#  '1966,',
#  'which',
#  'found',
#  'that',
#  'ten-year-long',
#  'research',
#  'had',
#  'failed',
#  'to',
#  'fulfill',
#  'the',
#  'expectations,',
#  'funding',
#  'for',
#  'machine',
#  'translation',
#  'was',
#  'dramatically',
#  'reduced.',
#  'Little',
#  'further',
#  'research',
#  'in',
#  'machine',
#  'translation',
#  'was',
#  'conducted',
#  'until',
#  'the',
#  'late',
#  '1980s',
#  'when',
#  'the',
#  'first',
#  'statistical',
#  'machine',
#  'translation',
#  'systems',
#  'were',
#  'developed.',
#  '\\n1960s:',
#  'Some',
#  'notably',
#  'successful',
#  'natural',
#  'language',
#  'processing',
#  'systems',
#  'developed',
#  'in',
#  'the',
#  '1960s',
#  'were',
#  'SHRDLU,',
#  'a',
#  'natural',
#  'language',
#  'system',
#  'working',
#  'in',
#  'restricted',
#  '"blocks',
#  'worlds"',
#  'with',
#  'restricted',
#  'vocabularies,',
#  'and',
#  'ELIZA,',
#  'a',
#  'simulation',
#  'of',
#  'a',
#  'Rogerian',
#  'psychotherapist,',
#  'written',
#  'by',
#  'Joseph',
#  'Weizenbaum',
#  'between',
#  '1964',
#  'and',
#  '1966.',
#  'Using',
#  'almost',
#  'no',
#  'information',
#  'about',
#  'human',
#  'thought',
#  'or',
#  'emotion,',
#  'ELIZA',
#  'sometimes',
#  'provided',
#  'a',
#  'startlingly',
#  'human-like',
#  'interaction.',
#  'When',
#  'the',
#  '"patient"',
#  'exceeded',
#  'the',
#  'very',
#  'small',
#  'knowledge',
#  'base,',
#  'ELIZA',
#  'might',
#  'provide',
#  'a',
#  'generic',
#  'response,',
#  'for',
#  'example,',
#  'responding',
#  'to',
#  '"My',
#  'head',
#  'hurts"',
#  'with',
#  '"Why',
#  'do',
#  'you',
#  'say',
#  'your',
#  'head',
#  'hurts?".',
#  '\\n1970s:',
#  'During',
#  'the',
#  '1970s,',
#  'many',
#  'programmers',
#  'began',
#  'to',
#  'write',
#  '"conceptual',
#  'ontologies",',
#  'which',
#  'structured',
#  'real-world',
#  'information',
#  'into',
#  'computer-understandable',
#  'data.',
#  'Examples',
#  'are',
#  'MARGIE',
#  '(Schank,',
#  '1975),',
#  'SAM',
#  '(Cullingford,',
#  '1978),',
#  'PAM',
#  '(Wilensky,',
#  '1978),',
#  'TaleSpin',
#  '(Meehan,',
#  '1976),',
#  'QUALM',
#  '(Lehnert,',
#  '1977),',
#  'Politics',
#  '(Carbonell,',
#  '1979),',
#  'and',
#  'Plot',
#  'Units',
#  '(Lehnert',
#  '1981).',
#  'During',
#  'this',
#  'time,',
#  'the',
#  'first',
#  'many',
#  'chatterbots',
#  'were',
#  'written',
#  '(e.g.,',
#  'PARRY).',
#  '\\n1980s:',
#  'The',
#  '1980s',
#  'and',
#  'early',
#  '1990s',
#  'mark',
#  'the',
#  'hey-day',
#  'of',
#  'symbolic',
#  'methods',
#  'in',
#  'NLP.',
#  'Focus',
#  'areas',
#  'of',
#  'the',
#  'time',
#  'included',
#  'research',
#  'on',
#  'rule-based',
#  'parsing',
#  '(e.g.,',
#  'the',
#  'development',
#  'of',
#  'HPSG',
#  'as',
#  'a',
#  'computational',
#  'operationalization',
#  'of',
#  'generative',
#  'grammar),',
#  'morphology',
#  '(e.g.,',
#  'two-level',
#  'morphology[3]),',
#  'semantics',
#  '(e.g.,',
#  'Lesk',
#  'algorithm),',
#  'reference',
#  '(e.g.,',
#  'within',
#  'Centering',
#  'Theory[4])',
#  'and',
#  'other',
#  'areas',
#  'of',
#  'natural',
#  'language',
#  'understanding',
#  '(e.g.,',
#  'in',
#  'the',
#  'Rhetorical',
#  'Structure',
#  'Theory).',
#  'Other',
#  'lines',
#  'of',
#  'research',
#  'were',
#  'continued,',
#  'e.g.,',
#  'the',
#  'development',
#  'of',
#  'chatterbots',
#  'with',
#  'Racter',
#  'and',
#  'Jabberwacky.',
#  'An',
#  'important',
#  'development',
#  '(that',
#  'eventually',
#  'led',
#  'to',
#  'the',
#  'statistical',
#  'turn',
#  'in',
#  'the',
#  '1990s)',
#  'was',
#  'the',
#  'rising',
#  'importance',
#  'of',
#  'quantitative',
#  'evaluation',
#  'in',
#  'this',
#  'period.[5]\\nStatistical',
#  'NLP',
#  '(1990s',
#  '-',
#  '2010s)\\nUp',
#  'to',
#  'the',
#  '1980s,',
#  'most',
#  'natural',
#  'language',
#  'processing',
#  'systems',
#  'were',
#  'based',
#  'on',
#  'complex',
#  'sets',
#  'of',
#  'hand-written',
#  'rules.',
#  'Starting',
#  'in',
#  'the',
#  'late',
#  '1980s,',
#  'however,',
#  'there',
#  'was',
#  'a',
#  'revolution',
#  'in',
#  'natural',
#  'language',
#  'processing',
#  'with',
#  'the',
#  'introduction',
#  'of',
#  'machine',
#  'learning',
#  'algorithms',
#  'for',
#  'language',
#  'processing.',
#  'This',
#  'was',
#  'due',
#  'to',
#  'both',
#  'the',
#  'steady',
#  'increase',
#  'in',
#  'computational',
#  'power',
#  '(see',
#  "Moore\\'s",
#  'law)',
#  'and',
#  'the',
#  'gradual',
#  'lessening',
#  'of',
#  'the',
#  'dominance',
#  'of',
#  'Chomskyan',
#  'theories',
#  'of',
#  'linguistics',
#  '(e.g.',
#  'transformational',
#  'grammar),',
#  'whose',
#  'theoretical',
#  'underpinnings',
#  'discouraged',
#  'the',
#  'sort',
#  'of',
#  'corpus',
#  'linguistics',
#  'that',
#  'underlies',
#  'the',
#  'machine-learning',
#  'approach',
#  'to',
#  'language',
#  'processing.[6]',
#  '\\n1990s:',
#  'Many',
#  'of',
#  'the',
#  'notable',
#  'early',
#  'successes',
#  'on',
#  'statistical',
#  'methods',
#  'in',
#  'NLP',
#  'occurred',
#  'in',
#  'the',
#  'field',
#  'of',
#  'machine',
#  'translation,',
#  'due',
#  'especially',
#  'to',
#  'work',
#  'at',
#  'IBM',
#  'Research.',
#  'These',
#  'systems',
#  'were',
#  'able',
#  'to',
#  'take',
#  'advantage',
#  'of',
#  'existing',
#  'multilingual',
#  'textual',
#  'corpora',
#  'that',
#  'had',
#  'been',
#  'produced',
#  'by',
#  'the',
#  'Parliament',
#  'of',
#  'Canada',
#  'and',
#  'the',
#  'European',
#  'Union',
#  'as',
#  'a',
#  'result',
#  'of',
#  'laws',
#  'calling',
#  'for',
#  'the',
#  'translation',
#  'of',
#  'all',
#  'governmental',
#  'proceedings',
#  'into',
#  'all',
#  'official',
#  'languages',
#  'of',
#  'the',
#  'corresponding',
#  'systems',
#  'of',
#  'government.',
#  'However,',
#  'most',
#  'other',
#  'systems',
#  'depended',
#  'on',
#  'corpora',
#  'specifically',
#  'developed',
#  'for',
#  'the',
#  'tasks',
#  'implemented',
#  'by',
#  'these',
#  'systems,',
#  'which',
#  'was',
#  '(and',
#  'often',
#  'continues',
#  'to',
#  'be)',
#  'a',
#  'major',
#  'limitation',
#  'in',
#  'the',
#  'success',
#  'of',
#  'these',
#  'systems.',
#  'As',
#  'a',
#  'result,',
#  'a',
#  'great',
#  'deal',
#  'of',
#  'research',
#  'has',
#  'gone',
#  'into',
#  'methods',
#  'of',
#  'more',
#  'effectively',
#  'learning',
#  'from',
#  'limited',
#  'amounts',
#  'of',
#  'data.',
#  '\\n2000s:',
#  'With',
#  'the',
#  'growth',
#  'of',
#  'the',
#  'web,',
#  'increasing',
#  'amounts',
#  'of',
#  'raw',
#  '(unannotated)',
#  'language',
#  'data',
#  'has',
#  'become',
#  'available',
#  'since',
#  'the',
#  'mid-1990s.',
#  'Research',
#  'has',
#  'thus',
#  'increasingly',
#  'focused',
#  'on',
#  'unsupervised',
#  'and',
#  'semi-supervised',
#  'learning',
#  'algorithms.',
#  'Such',
#  'algorithms',
#  'can',
#  'learn',
#  'from',
#  'data',
#  'that',
#  'has',
#  'not',
#  'been',
#  'hand-annotated',
#  'with',
#  'the',
#  'desired',
#  'answers',
#  'or',
#  'using',
#  'a',
#  'combination',
#  'of',
#  'annotated',
#  'and',
#  'non-annotated',
#  'data.',
#  'Generally,',
#  'this',
#  'task',
#  'is',
#  'much',
#  'more',
#  'difficult',
#  'than',
#  'supervised',
#  'learning,',
#  'and',
#  'typically',
#  'produces',
#  'less',
#  'accurate',
#  'results',
#  'for',
#  'a',
#  'given',
#  'amount',
#  'of',
#  'input',
#  'data.',
#  'However,',
#  'there',
#  'is',
#  'an',
#  'enormous',
#  'amount',
#  'of',
#  'non-annotated',
#  'data',
#  'available',
#  '(including,',
#  'among',
#  'other',
#  'things,',
#  'the',
#  'entire',
#  'content',
#  'of',
#  'the',
#  'World',
#  'Wide',
#  'Web),',
#  'which',
#  'can',
#  'often',
#  'make',
#  'up',
#  'for',
#  'the',
#  'inferior',
#  'results',
#  'if',
#  'the',
#  'algorithm',
#  'used',
#  'has',
#  'a',
#  'low',
#  'enough',
#  'time',
#  'complexity',
#  'to',
#  'be',
#  'practical.\\nNeural',
#  'NLP',
#  '(present)\\nIn',
#  'the',
#  '2010s,',
#  'representation',
#  'learning',
#  'and',
#  'deep',
#  'neural',
#  'network-style',
#  'machine',
#  'learning',
#  'methods',
#  'became',
#  'widespread',
#  'in',
#  'natural',
#  'language',
#  'processing,',
#  'due',
#  'in',
#  'part',
#  'to',
#  'a',
#  'flurry',
#  'of',
#  'results',
#  'showing',
#  'that',
#  'such',
#  'techniques[7][8]',
#  'can',
#  'achieve',
#  'state-of-the-art',
#  'results',
#  'in',
#  'many',
#  'natural',
#  'language',
#  'tasks,',
#  'for',
#  'example',
#  'in',
#  'language',
#  'modeling,[9]',
#  'parsing,[10][11]',
#  'and',
#  'many',
#  'others.',
#  '\\nMethods:',
#  'Rules,',
#  'statistics,',
#  'neural',
#  'networks\\nIn',
#  'the',
#  'early',
#  'days,',
#  'many',
#  'language-processing',
#  'systems',
#  'were',
#  'designed',
#  'by',
#  'symbolic',
#  'methods,',
#  'i.e.,',
#  'the',
#  'hand-coding',
#  'of',
#  'a',
#  'set',
#  'of',
#  'rules,',
#  'coupled',
#  'with',
#  'a',
#  'dictionary',
#  'lookup:[12][13]',
#  'such',
#  'as',
#  'by',
#  'writing',
#  'grammars',
#  'or',
#  'devising',
#  'heuristic',
#  'rules',
#  'for',
#  'stemming.',
#  '\\nMore',
#  'recent',
#  'systems',
#  'based',
#  'on',
#  'machine-learning',
#  'algorithms',
#  'have',
#  'many',
#  'advantages',
#  'over',
#  'hand-produced',
#  'rules:',
#  '\\nThe',
#  'learning',
#  'procedures',
#  'used',
#  'during',
#  'machine',
#  'learning',
#  'automatically',
#  'focus',
#  'on',
#  'the',
#  'most',
#  'common',
#  'cases,',
#  'whereas',
#  'when',
#  'writing',
#  'rules',
#  'by',
#  'hand',
#  'it',
#  'is',
#  'often',
#  'not',
#  'at',
#  'all',
#  'obvious',
#  'where',
#  'the',
#  'effort',
#  'should',
#  'be',
#  'directed.',
#  '\\nAutomatic',
#  'learning',
#  'procedures',
#  'can',
#  'make',
#  'use',
#  'of',
#  'statistical',
#  'inference',
#  'algorithms',
#  'to',
#  'produce',
#  'models',
#  'that',
#  'are',
#  'robust',
#  'to',
#  'unfamiliar',
#  'input',
#  '(e.g.',
#  'containing',
#  'words',
#  'or',
#  'structures',
#  'that',
#  'have',
#  'not',
#  'been',
#  'seen',
#  'before)',
#  'and',
#  'to',
#  'erroneous',
#  'input',
#  '(e.g.',
#  'with',
#  'misspelled',
#  'words',
#  'or',
#  'words',
#  'accidentally',
#  'omitted).',
#  'Generally,',
#  'handling',
#  'such',
#  'input',
#  'gracefully',
#  'with',
#  'handwritten',
#  'rules,',
#  'or,',
#  'more',
#  'generally,',
#  'creating',
#  'systems',
#  'of',
#  'handwritten',
#  'rules',
#  'that',
#  'make',
#  'soft',
#  'decisions,',
#  'is',
#  'extremely',
#  'difficult,',
#  'error-prone',
#  'and',
#  'time-consuming.',
#  '\\nSystems',
#  'based',
#  'on',
#  'automatically',
#  'learning',
#  'the',
#  'rules',
#  'can',
#  'be',
#  'made',
#  'more',
#  'accurate',
#  'simply',
#  'by',
#  'supplying',
#  'more',
#  ...]

# %%
vect.fit(text1)
# Out:
# CountVectorizer(analyzer='word', binary=True, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 1), preprocessor=None, stop_words=None,
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
vocab = vect.vocabulary_
vocab
# Out:
# {'natural': 650,
#  'language': 545,
#  'processing': 832,
#  'has': 456,
#  'its': 536,
#  'roots': 921,
#  'in': 491,
#  'the': 1059,
#  '1950s': 11,
#  'already': 73,
#  '1950': 10,
#  'alan': 63,
#  'turing': 1096,
#  'published': 852,
#  'an': 82,
#  'article': 109,
#  'titled': 1078,
#  'computing': 224,
#  'machinery': 585,
#  'and': 87,
#  'intelligence': 516,
#  'which': 1149,
#  'proposed': 845,
#  'what': 1144,
#  'is': 533,
#  'now': 710,
#  'called': 165,
#  'test': 1053,
#  'as': 113,
#  'criterion': 262,
#  'of': 747,
#  'task': 1045,
#  'that': 1058,
#  'involves': 530,
#  'automated': 124,
#  'interpretation': 524,
#  'generation': 427,
#  'but': 162,
#  'at': 120,
#  'time': 1077,
#  'not': 703,
#  'articulated': 111,
#  'problem': 826,
#  'separate': 951,
#  'from': 416,
#  'artificial': 112,
#  'nsymbolic': 727,
#  'nlp': 687,
#  'early': 317,
#  '1990s': 25,
#  'nthe': 732,
#  'premise': 818,
#  'symbolic': 1035,
#  'well': 1141,
#  'summarized': 1030,
#  'by': 163,
#  'john': 539,
#  'searle': 933,
#  'chinese': 189,
#  'room': 919,
#  'experiment': 368,
#  'given': 433,
#  'collection': 208,
#  'rules': 924,
#  'phrasebook': 797,
#  'with': 1159,
#  'questions': 858,
#  'matching': 605,
#  'answers': 94,
#  'computer': 223,
#  'emulates': 334,
#  'understanding': 1108,
#  'or': 766,
#  'other': 771,
#  'tasks': 1046,
#  'applying': 101,
#  'those': 1071,
#  'to': 1079,
#  'data': 266,
#  'it': 534,
#  'confronted': 229,
#  'n1950s': 640,
#  'georgetown': 431,
#  '1954': 12,
#  'involved': 529,
#  'fully': 420,
#  'automatic': 125,
#  'translation': 1089,
#  'more': 630,
#  'than': 1057,
#  'sixty': 971,
#  'russian': 925,
#  'sentences': 949,
#  'into': 526,
#  'english': 339,
#  'authors': 123,
#  'claimed': 193,
#  'within': 1160,
#  'three': 1074,
#  'five': 395,
#  'years': 1190,
#  'machine': 584,
#  'would': 1171,
#  'be': 134,
#  'solved': 981,
#  'however': 469,
#  'real': 864,
#  'progress': 839,
#  'was': 1136,
#  'much': 634,
#  'slower': 972,
#  'after': 58,
#  'alpac': 72,
#  'report': 890,
#  '1966': 15,
#  'found': 410,
#  'ten': 1048,
#  'year': 1189,
#  'long': 580,
#  'research': 898,
#  'had': 449,
#  'failed': 384,
#  'fulfill': 418,
#  'expectations': 365,
#  'funding': 421,
#  'for': 403,
#  'dramatically': 308,
#  'reduced': 870,
#  'little': 575,
#  'further': 422,
#  'conducted': 228,
#  'until': 1115,
#  'late': 550,
#  '1980s': 22,
#  'when': 1145,
#  'first': 394,
#  'statistical': 1003,
#  'systems': 1039,
#  'were': 1142,
#  'developed': 284,
#  'n1960s': 641,
#  'some': 983,
#  'notably': 705,
#  'successful': 1024,
#  '1960s': 13,
#  'shrdlu': 962,
#  'system': 1038,
#  'working': 1167,
#  'restricted': 905,
#  'blocks': 150,
#  'worlds': 1170,
#  'vocabularies': 1133,
#  'eliza': 327,
#  'simulation': 968,
#  'rogerian': 916,
#  'psychotherapist': 850,
#  'written': 1175,
#  'joseph': 540,
#  'weizenbaum': 1140,
#  'between': 146,
#  '1964': 14,
#  'using': 1122,
#  'almost': 70,
#  'no': 699,
#  'information': 510,
#  'about': 43,
#  'human': 471,
#  'thought': 1072,
#  'emotion': 330,
#  'sometimes': 984,
#  'provided': 847,
#  'startlingly': 1000,
#  'like': 566,
#  'interaction': 520,
#  'patient': 788,
#  'exceeded': 363,
#  'very': 1129,
#  'small': 973,
#  'knowledge': 541,
#  'base': 129,
#  'might': 621,
#  'provide': 846,
#  'generic': 429,
#  'response': 904,
#  'example': 361,
#  'responding': 903,
#  'my': 639,
#  'head': 459,
#  'hurts': 473,
#  'why': 1154,
#  'do': 304,
#  'you': 1192,
#  'say': 928,
#  'your': 1193,
#  'n1970s': 642,
#  'during': 314,
#  '1970s': 16,
#  'many': 594,
#  'programmers': 837,
#  'began': 141,
#  'write': 1172,
#  'conceptual': 226,
#  'ontologies': 757,
#  'structured': 1013,
#  'world': 1169,
#  'understandable': 1107,
#  'examples': 362,
#  'are': 105,
#  'margie': 596,
#  'schank': 929,
#  '1975': 17,
#  'sam': 926,
#  'cullingford': 263,
#  '1978': 20,
#  'pam': 776,
#  'wilensky': 1157,
#  'talespin': 1044,
#  'meehan': 610,
#  '1976': 18,
#  'qualm': 855,
#  'lehnert': 557,
#  '1977': 19,
#  'politics': 806,
#  'carbonell': 177,
#  '1979': 21,
#  'plot': 802,
#  'units': 1111,
#  '1981': 23,
#  'this': 1070,
#  'chatterbots': 188,
#  'parry': 780,
#  'n1980s': 643,
#  'mark': 597,
#  'hey': 462,
#  'day': 268,
#  'methods': 619,
#  'focus': 399,
#  'areas': 106,
#  'included': 494,
#  'on': 752,
#  'rule': 923,
#  'based': 130,
#  'parsing': 783,
#  'development': 285,
#  'hpsg': 470,
#  'computational': 222,
#  'operationalization': 763,
#  'generative': 428,
#  'grammar': 440,
#  'morphology': 632,
#  'two': 1099,
#  'level': 564,
#  'semantics': 943,
#  'lesk': 559,
#  'algorithm': 64,
#  'reference': 873,
#  'centering': 181,
#  'theory': 1065,
#  'rhetorical': 911,
#  'structure': 1012,
#  'lines': 571,
#  'continued': 245,
#  'racter': 859,
#  'jabberwacky': 537,
#  'important': 490,
#  'eventually': 360,
#  'led': 556,
#  'turn': 1098,
#  'rising': 913,
#  'importance': 489,
#  'quantitative': 856,
#  'evaluation': 358,
#  'period': 793,
#  'nstatistical': 725,
#  '2010s': 27,
#  'nup': 737,
#  'most': 633,
#  'complex': 218,
#  'sets': 956,
#  'hand': 451,
#  'starting': 999,
#  'there': 1066,
#  'revolution': 910,
#  'introduction': 528,
#  'learning': 554,
#  'algorithms': 65,
#  'due': 313,
#  'both': 153,
#  'steady': 1006,
#  'increase': 497,
#  'power': 815,
#  'see': 935,
#  'moore': 629,
#  'law': 551,
#  'gradual': 439,
#  'lessening': 561,
#  'dominance': 306,
#  'chomskyan': 190,
#  'theories': 1064,
#  'linguistics': 572,
#  'transformational': 1085,
#  'whose': 1153,
#  'theoretical': 1063,
#  'underpinnings': 1106,
#  'discouraged': 297,
#  'sort': 986,
#  'corpus': 256,
#  'underlies': 1105,
#  'approach': 102,
#  'n1990s': 644,
#  'notable': 704,
#  'successes': 1023,
#  'occurred': 745,
#  'field': 390,
#  'especially': 355,
#  'work': 1165,
#  'ibm': 474,
#  'these': 1067,
#  'able': 42,
#  'take': 1042,
#  'advantage': 56,
#  'existing': 364,
#  'multilingual': 635,
#  'textual': 1055,
#  'corpora': 255,
#  'been': 139,
#  'produced': 834,
#  'parliament': 779,
#  'canada': 169,
#  'european': 357,
#  'union': 1110,
#  'result': 906,
#  'laws': 552,
#  'calling': 166,
#  'all': 68,
#  'governmental': 437,
#  'proceedings': 829,
#  'official': 749,
#  'languages': 546,
#  'corresponding': 257,
#  'government': 436,
#  'depended': 275,
#  'specifically': 994,
#  'implemented': 485,
#  'often': 750,
#  'continues': 246,
#  'major': 587,
#  'limitation': 569,
#  'success': 1022,
#  'great': 444,
#  'deal': 270,
#  'gone': 435,
#  'effectively': 319,
#  'limited': 570,
#  'amounts': 80,
#  'n2000s': 645,
#  'growth': 448,
#  'web': 1138,
#  'increasing': 499,
#  'raw': 861,
#  'unannotated': 1104,
#  'become': 138,
#  'available': 127,
#  'since': 969,
#  'mid': 620,
#  'thus': 1076,
#  'increasingly': 500,
#  'focused': 400,
#  'unsupervised': 1114,
#  'semi': 944,
#  'supervised': 1032,
#  'such': 1027,
#  'can': 168,
#  'learn': 553,
#  'annotated': 88,
#  'desired': 281,
#  'combination': 210,
#  'non': 700,
#  'generally': 425,
#  'difficult': 290,
#  'typically': 1103,
#  'produces': 835,
#  'less': 560,
#  'accurate': 48,
#  'results': 907,
#  'amount': 79,
#  'input': 511,
#  'enormous': 340,
#  'including': 496,
#  'among': 78,
#  'things': 1069,
#  'entire': 346,
#  'content': 241,
#  'wide': 1155,
#  'make': 588,
#  'up': 1116,
#  'inferior': 506,
#  'if': 481,
#  'used': 1120,
#  'low': 583,
#  'enough': 341,
#  'complexity': 219,
#  'practical': 816,
#  'nneural': 697,
#  'present': 820,
#  'nin': 683,
#  'representation': 891,
#  'deep': 273,
#  'neural': 671,
#  'network': 669,
#  'style': 1016,
#  'became': 136,
#  'widespread': 1156,
#  'part': 784,
#  'flurry': 398,
#  'showing': 961,
#  'techniques': 1047,
#  'achieve': 49,
#  'state': 1001,
#  'art': 108,
#  'modeling': 627,
#  '10': 0,
#  '11': 1,
#  'others': 772,
#  'nmethods': 691,
#  'statistics': 1004,
#  'networks': 670,
#  'days': 269,
#  'designed': 280,
#  'coding': 206,
#  'set': 955,
#  'coupled': 258,
#  'dictionary': 288,
#  'lookup': 582,
#  '12': 2,
#  '13': 3,
#  'writing': 1174,
#  'grammars': 441,
#  'devising': 286,
#  'heuristic': 461,
#  'stemming': 1007,
#  'nmore': 692,
#  'recent': 866,
#  'have': 457,
#  'advantages': 57,
#  'over': 775,
#  'procedures': 828,
#  'automatically': 126,
#  'common': 212,
#  'cases': 179,
#  'whereas': 1147,
#  'obvious': 744,
#  'where': 1146,
#  'effort': 321,
#  'should': 960,
#  'directed': 293,
#  'nautomatic': 652,
#  'use': 1119,
#  'inference': 505,
#  'produce': 833,
#  'models': 628,
#  'robust': 915,
#  'unfamiliar': 1109,
#  'containing': 239,
#  'words': 1164,
#  'structures': 1014,
#  'seen': 937,
#  'before': 140,
#  'erroneous': 352,
#  'misspelled': 625,
#  'accidentally': 46,
#  'omitted': 751,
#  'handling': 452,
#  'gracefully': 438,
#  'handwritten': 453,
#  'creating': 260,
#  'soft': 977,
#  'decisions': 272,
#  'extremely': 380,
#  'error': 353,
#  'prone': 840,
#  'consuming': 238,
#  'nsystems': 729,
#  'made': 586,
#  'simply': 967,
#  'supplying': 1033,
#  'only': 756,
#  'particular': 785,
#  'limit': 568,
#  'beyond': 147,
#  'unmanageable': 1113,
#  'requires': 896,
#  'number': 736,
#  'man': 591,
#  'hours': 466,
#  'worked': 1166,
#  'without': 1161,
#  'significant': 964,
#  'increases': 498,
#  'annotation': 89,
#  'process': 830,
#  'ndespite': 660,
#  'popularity': 808,
#  'still': 1009,
#  '2020': 30,
#  'commonly': 213,
#  'nwhen': 739,
#  'training': 1083,
#  'insufficient': 514,
#  'successfully': 1025,
#  'apply': 100,
#  'resource': 902,
#  'apertium': 96,
#  'nfor': 675,
#  'preprocessing': 819,
#  'pipelines': 800,
#  'tokenization': 1080,
#  'postprocessing': 813,
#  'transforming': 1087,
#  'output': 774,
#  'extraction': 379,
#  'syntactic': 1036,
#  'parses': 782,
#  'nsince': 722,
#  'so': 975,
#  '14': 4,
#  '15': 5,
#  'relied': 884,
#  'heavily': 460,
#  'paradigm': 778,
#  'calls': 167,
#  'instead': 513,
#  'through': 1075,
#  'analysis': 85,
#  'large': 547,
#  'plural': 803,
#  'form': 404,
#  'documents': 305,
#  'possibly': 812,
#  'annotations': 90,
#  'typical': 1102,
#  'nmany': 690,
#  'different': 289,
#  'classes': 195,
#  'applied': 99,
#  'features': 389,
#  'generated': 426,
#  'probabilistic': 825,
#  'attaching': 121,
#  'valued': 1124,
#  'weights': 1139,
#  'each': 315,
#  'feature': 388,
#  'they': 1068,
#  'express': 373,
#  'relative': 881,
#  'certainty': 182,
#  'possible': 811,
#  'rather': 860,
#  'one': 753,
#  'producing': 836,
#  'reliable': 883,
#  'model': 626,
#  'component': 220,
#  'larger': 549,
#  'nsome': 723,
#  'earliest': 316,
#  'decision': 271,
#  'trees': 1092,
#  'hard': 454,
#  'then': 1062,
#  'similar': 965,
#  'speech': 996,
#  'tagging': 1041,
#  'introduced': 527,
#  'hidden': 463,
#  'markov': 602,
#  'making': 590,
#  'cache': 164,
#  'upon': 1117,
#  'recognition': 867,
#  'rely': 885,
#  'contains': 240,
#  'errors': 354,
#  'integrated': 515,
#  'comprising': 221,
#  'multiple': 637,
#  'subtasks': 1021,
#  'largely': 548,
#  'replaced': 889,
#  'continue': 244,
#  'relevant': 882,
#  'contexts': 243,
#  'interpretability': 523,
#  'transparency': 1090,
#  'required': 895,
#  'nfurther': 676,
#  'na': 646,
#  'drawback': 309,
#  'require': 894,
#  'elaborate': 323,
#  'engineering': 338,
#  '16': 6,
#  'abandoned': 40,
#  'shifted': 959,
#  'popular': 807,
#  'include': 493,
#  'word': 1162,
#  'embeddings': 329,
#  'capture': 176,
#  'semantic': 942,
#  'properties': 844,
#  'end': 335,
#  'higher': 464,
#  'question': 857,
#  'answering': 93,
#  'relying': 886,
#  'pipeline': 799,
#  'intermediate': 522,
#  'dependency': 276,
#  'shift': 958,
#  'entailed': 342,
#  'substantial': 1019,
#  'changes': 185,
#  'how': 468,
#  'approaches': 103,
#  'may': 606,
#  'viewed': 1131,
#  'new': 672,
#  'distinct': 301,
#  'instance': 512,
#  'term': 1049,
#  'nmt': 694,
#  'emphasizes': 331,
#  'fact': 381,
#  'directly': 294,
#  'sequence': 953,
#  'transformations': 1086,
#  'obviating': 743,
#  'need': 666,
#  'steps': 1008,
#  'alignment': 66,
#  'smt': 974,
#  'ncommon': 656,
#  'following': 402,
#  'list': 573,
#  'researched': 899,
#  'direct': 292,
#  'applications': 98,
#  'while': 1150,
#  'serve': 954,
#  'aid': 62,
#  'solving': 982,
#  'nthough': 734,
#  'closely': 201,
#  'intertwined': 525,
#  'subdivided': 1017,
#  'categories': 180,
#  'convenience': 249,
#  'coarse': 204,
#  'division': 303,
#  'below': 144,
#  'ntext': 731,
#  'noptical': 702,
#  'character': 186,
#  'ocr': 746,
#  'ngiven': 678,
#  'image': 483,
#  'representing': 893,
#  'printed': 823,
#  'text': 1054,
#  'determine': 282,
#  'nspeech': 724,
#  'sound': 987,
#  'clip': 198,
#  'person': 795,
#  'people': 791,
#  'speaking': 992,
#  'opposite': 765,
#  'problems': 827,
#  'colloquially': 209,
#  'termed': 1050,
#  'ai': 61,
#  'complete': 216,
#  'above': 44,
#  'hardly': 455,
#  'any': 95,
#  'pauses': 789,
#  'successive': 1026,
#  'segmentation': 939,
#  'necessary': 665,
#  'subtask': 1020,
#  'spoken': 997,
#  'sounds': 988,
#  'letters': 563,
#  'blend': 149,
#  'coarticulation': 205,
#  'conversion': 251,
#  'analog': 83,
#  'signal': 963,
#  'discrete': 299,
#  'characters': 187,
#  'also': 74,
#  'same': 927,
#  'accents': 45,
#  'software': 978,
#  'must': 638,
#  'recognize': 868,
#  'variety': 1125,
#  'being': 143,
#  'identical': 476,
#  'terms': 1052,
#  'equivalent': 351,
#  'grouped': 447,
#  'transform': 1084,
#  'visually': 1132,
#  'impaired': 484,
#  '17': 7,
#  'nword': 740,
#  'nseparate': 721,
#  'chunk': 191,
#  'continuous': 247,
#  'fairly': 385,
#  'trivial': 1094,
#  'usually': 1123,
#  'separated': 952,
#  'spaces': 989,
#  'japanese': 538,
#  'thai': 1056,
#  'boundaries': 154,
#  'fashion': 387,
#  'requiring': 897,
#  'vocabulary': 1134,
#  'bag': 128,
#  'bow': 156,
#  'creation': 261,
#  'mining': 624,
#  'nmorphological': 693,
#  'nlemmatization': 684,
#  'removing': 888,
#  'inflectional': 509,
#  'endings': 337,
#  'return': 908,
#  'known': 542,
#  'lemma': 558,
#  'individual': 503,
#  'morphemes': 631,
#  'identify': 479,
#  'class': 194,
#  'difficulty': 291,
#  'depends': 277,
#  'greatly': 445,
#  'considered': 233,
#  'simple': 966,
#  'ignore': 482,
#  'entirely': 347,
#  'forms': 409,
#  'open': 759,
#  'opens': 762,
#  'opened': 760,
#  'opening': 761,
#  'turkish': 1097,
#  'meitei': 611,
#  '18': 8,
#  'highly': 465,
#  'agglutinated': 60,
#  'indian': 501,
#  'entry': 350,
#  'thousands': 1073,
#  'npart': 712,
#  'sentence': 948,
#  'pos': 809,
#  'ones': 754,
#  'parts': 787,
#  'book': 151,
#  'noun': 707,
#  'table': 1040,
#  'verb': 1126,
#  'flight': 397,
#  'adjective': 54,
#  'out': 773,
#  'least': 555,
#  'ambiguity': 76,
#  'dubious': 312,
#  'xe2': 1188,
#  'x80': 1176,
#  'x93': 1177,
#  'discuss': 300,
#  'particularly': 786,
#  'because': 137,
#  'tonal': 1081,
#  'verbalization': 1128,
#  'inflection': 508,
#  'readily': 863,
#  'conveyed': 253,
#  'via': 1130,
#  'entities': 348,
#  'employed': 333,
#  'orthography': 770,
#  'convey': 252,
#  'intended': 517,
#  'meaning': 607,
#  'nstemming': 726,
#  'reducing': 871,
#  'inflected': 507,
#  'derived': 278,
#  'their': 1060,
#  'root': 920,
#  'close': 199,
#  'will': 1158,
#  'closed': 200,
#  'closing': 203,
#  'closer': 202,
#  'etc': 356,
#  'nsyntactic': 728,
#  'ngrammar': 679,
#  'induction': 504,
#  '19': 9,
#  'ngenerate': 677,
#  'formal': 405,
#  'describes': 279,
#  'syntax': 1037,
#  'nsentence': 719,
#  'breaking': 158,
#  'boundary': 155,
#  'disambiguation': 296,
#  'find': 392,
#  'marked': 598,
#  'periods': 794,
#  'punctuation': 853,
#  'marks': 603,
#  'purposes': 854,
#  'marking': 601,
#  'abbreviations': 41,
#  'nparsing': 711,
#  'ndetermine': 661,
#  'parse': 781,
#  'tree': 1091,
#  'grammatical': 442,
#  'ambiguous': 77,
#  'analyses': 84,
#  'perhaps': 792,
#  'surprisingly': 1034,
#  'potential': 814,
#  'seem': 936,
#  'completely': 217,
#  'nonsensical': 701,
#  'primary': 822,
#  'types': 1101,
#  'constituency': 235,
#  'focuses': 401,
#  'relationships': 880,
#  'objects': 742,
#  'predicates': 817,
#  'building': 161,
#  'context': 242,
#  'free': 414,
#  'pcfg': 790,
#  'stochastic': 1010,
#  'nlexical': 685,
#  'nwhat': 738,
#  'ndistributional': 664,
#  'nhow': 681,
#  'we': 1137,
#  'representations': 892,
#  'nnamed': 695,
#  'entity': 349,
#  'ner': 668,
#  'stream': 1011,
#  'items': 535,
#  'map': 595,
#  'proper': 842,
#  'names': 649,
#  'places': 801,
#  'type': 1100,
#  'name': 647,
#  'location': 577,
#  'organization': 768,
#  'although': 75,
#  'capitalization': 172,
#  'recognizing': 869,
#  'named': 648,
#  'cannot': 170,
#  'determining': 283,
#  'case': 178,
#  'inaccurate': 492,
#  'letter': 562,
#  'capitalized': 174,
#  'span': 990,
#  'several': 957,
#  'furthermore': 423,
#  'western': 1143,
#  'scripts': 932,
#  'arabic': 104,
#  'even': 359,
#  'consistently': 234,
#  'distinguish': 302,
#  'german': 432,
#  'capitalizes': 175,
#  'nouns': 708,
#  'regardless': 877,
#  'whether': 1148,
#  'french': 415,
#  'spanish': 991,
#  'capitalize': 173,
#  'adjectives': 55,
#  'nsentiment': 720,
#  'multimodal': 636,
#  'sentiment': 950,
#  'nextract': 674,
#  'subjective': 1018,
#  'online': 755,
#  'reviews': 909,
#  'polarity': 804,
#  'specific': 993,
#  'useful': 1121,
#  'identifying': 480,
#  'trends': 1093,
#  'public': 851,
#  'opinion': 764,
#  'social': 976,
#  'media': 609,
#  'marketing': 600,
#  'nterminology': 730,
#  'goal': 434,
#  'terminology': 1051,
#  'extract': 378,
#  'sense': 945,
#  'select': 941,
#  'makes': 589,
#  'associated': 117,
#  'senses': 946,
#  'wordnet': 1163,
#  'nrelational': 716,
#  'nrelationship': 717,
#  'who': 1151,
#  'married': 604,
#  'whom': 1152,
#  'nsemantic': 718,
#  'piece': 798,
#  'either': 322,
#  'graph': 443,
#  'amr': 81,
#  'accordance': 47,
#  'logical': 579,
#  'formalism': 406,
#  'drt': 311,
#  'challenge': 183,
#  'includes': 495,
#  'aspects': 115,
#  'elementary': 325,
#  'role': 917,
#  'labelling': 543,
#  'extended': 376,
#  'full': 419,
#  'fledged': 396,
#  'discourse': 298,
#  'coreference': 254,
#  'implicit': 487,
#  'single': 970,
#  'disambiguate': 295,
#  'verbal': 1127,
#  'frames': 413,
#  'classify': 196,
#  'frame': 412,
#  'elements': 326,
#  'roles': 918,
#  'ndiscourse': 663,
#  'ncoreference': 659,
#  'resolution': 900,
#  'mentions': 614,
#  'refer': 872,
#  'anaphora': 86,
#  'concerned': 227,
#  'pronouns': 841,
#  'general': 424,
#  'bridging': 159,
#  'involving': 531,
#  'referring': 875,
#  'expressions': 375,
#  'he': 458,
#  'entered': 345,
#  'house': 467,
#  'front': 417,
#  'door': 307,
#  'expression': 374,
#  'relationship': 879,
#  'identified': 478,
#  'referred': 874,
#  'nthis': 733,
#  'rubric': 922,
#  'related': 878,
#  'connected': 231,
#  'nature': 651,
#  'elaboration': 324,
#  'explanation': 370,
#  'contrast': 248,
#  'another': 91,
#  'classifying': 197,
#  'acts': 52,
#  ...}

# %%
for key in sorted(vocab.keys()):
    print("{}:{}".format(key,vocab[key]))
# Out:
# 10:0
# 11:1
# 12:2
# 13:3
# 14:4
# 15:5
# 16:6
# 17:7
# 18:8
# 19:9
# 1950:10
# 1950s:11
# 1954:12
# 1960s:13
# 1964:14
# 1966:15
# 1970s:16
# 1975:17
# 1976:18
# 1977:19
# 1978:20
# 1979:21
# 1980s:22
# 1981:23
# 1984:24
# 1990s:25
# 20:26
# 2010s:27
# 2018:28
# 2019:29
# 2020:30
# 21:31
# 22:32
# 23:33
# 24:34
# 25:35
# 26:36
# 27:37
# 28:38
# 29:39
# abandoned:40
# abbreviations:41
# able:42
# about:43
# above:44
# accents:45
# accidentally:46
# accordance:47
# accurate:48
# achieve:49
# acquiring:50
# action:51
# acts:52
# additional:53
# adjective:54
# adjectives:55
# advantage:56
# advantages:57
# after:58
# against:59
# agglutinated:60
# ai:61
# aid:62
# alan:63
# algorithm:64
# algorithms:65
# alignment:66
# alike:67
# all:68
# allows:69
# almost:70
# along:71
# alpac:72
# already:73
# also:74
# although:75
# ambiguity:76
# ambiguous:77
# among:78
# amount:79
# amounts:80
# amr:81
# an:82
# analog:83
# analyses:84
# analysis:85
# anaphora:86
# and:87
# annotated:88
# annotation:89
# annotations:90
# another:91
# answer:92
# answering:93
# answers:94
# any:95
# apertium:96
# application:97
# applications:98
# applied:99
# apply:100
# applying:101
# approach:102
# approaches:103
# arabic:104
# are:105
# areas:106
# arguments:107
# art:108
# article:109
# articles:110
# articulated:111
# artificial:112
# as:113
# aspect:114
# aspects:115
# assertion:116
# associated:117
# assumption:118
# assumptions:119
# at:120
# attaching:121
# author:122
# authors:123
# automated:124
# automatic:125
# automatically:126
# available:127
# bag:128
# base:129
# based:130
# basically:131
# basis:132
# batteries:133
# be:134
# beard:135
# became:136
# because:137
# become:138
# been:139
# before:140
# began:141
# behind:142
# being:143
# below:144
# beta:145
# between:146
# beyond:147
# big:148
# blend:149
# blocks:150
# book:151
# books:152
# both:153
# boundaries:154
# boundary:155
# bow:156
# branch:157
# breaking:158
# bridging:159
# build:160
# building:161
# but:162
# by:163
# cache:164
# called:165
# calling:166
# calls:167
# can:168
# canada:169
# cannot:170
# capital:171
# capitalization:172
# capitalize:173
# capitalized:174
# capitalizes:175
# capture:176
# carbonell:177
# case:178
# cases:179
# categories:180
# centering:181
# certainty:182
# challenge:183
# cham:184
# changes:185
# character:186
# characters:187
# chatterbots:188
# chinese:189
# chomskyan:190
# chunk:191
# chunks:192
# claimed:193
# class:194
# classes:195
# classify:196
# classifying:197
# clip:198
# close:199
# closed:200
# closely:201
# closer:202
# closing:203
# coarse:204
# coarticulation:205
# coding:206
# cognitive:207
# collection:208
# colloquially:209
# combination:210
# combining:211
# common:212
# commonly:213
# comparative:214
# comparison:215
# complete:216
# completely:217
# complex:218
# complexity:219
# component:220
# comprising:221
# computational:222
# computer:223
# computing:224
# concepts:225
# conceptual:226
# concerned:227
# conducted:228
# confronted:229
# confusions:230
# connected:231
# consider:232
# considered:233
# consistently:234
# constituency:235
# constructed:236
# construction:237
# consuming:238
# containing:239
# contains:240
# content:241
# context:242
# contexts:243
# continue:244
# continued:245
# continues:246
# continuous:247
# contrast:248
# convenience:249
# converse:250
# conversion:251
# convey:252
# conveyed:253
# coreference:254
# corpora:255
# corpus:256
# corresponding:257
# coupled:258
# created:259
# creating:260
# creation:261
# criterion:262
# cullingford:263
# current:264
# cwa:265
# data:266
# databases:267
# day:268
# days:269
# deal:270
# decision:271
# decisions:272
# deep:273
# defining:274
# depended:275
# dependency:276
# depends:277
# derived:278
# describes:279
# designed:280
# desired:281
# determine:282
# determining:283
# developed:284
# development:285
# devising:286
# devoted:287
# dictionary:288
# different:289
# difficult:290
# difficulty:291
# direct:292
# directed:293
# directly:294
# disambiguate:295
# disambiguation:296
# discouraged:297
# discourse:298
# discrete:299
# discuss:300
# distinct:301
# distinguish:302
# division:303
# do:304
# documents:305
# dominance:306
# door:307
# dramatically:308
# drawback:309
# drop:310
# drt:311
# dubious:312
# due:313
# during:314
# each:315
# earliest:316
# early:317
# easier:318
# effectively:319
# efficient:320
# effort:321
# either:322
# elaborate:323
# elaboration:324
# elementary:325
# elements:326
# eliza:327
# elsewhere:328
# embeddings:329
# emotion:330
# emphasizes:331
# empirical:332
# employed:333
# emulates:334
# end:335
# ended:336
# endings:337
# engineering:338
# english:339
# enormous:340
# enough:341
# entailed:342
# entailment:343
# entails:344
# entered:345
# entire:346
# entirely:347
# entities:348
# entity:349
# entry:350
# equivalent:351
# erroneous:352
# error:353
# errors:354
# especially:355
# etc:356
# european:357
# evaluation:358
# even:359
# eventually:360
# example:361
# examples:362
# exceeded:363
# existing:364
# expectations:365
# expected:366
# experience:367
# experiment:368
# explained:369
# explanation:370
# explicit:371
# explicitly:372
# express:373
# expression:374
# expressions:375
# extended:376
# extension:377
# extract:378
# extraction:379
# extremely:380
# fact:381
# facts:382
# factual:383
# failed:384
# fairly:385
# false:386
# fashion:387
# feature:388
# features:389
# field:390
# financial:391
# find:392
# findings:393
# first:394
# five:395
# fledged:396
# flight:397
# flurry:398
# focus:399
# focused:400
# focuses:401
# following:402
# for:403
# form:404
# formal:405
# formalism:406
# formalization:407
# former:408
# forms:409
# found:410
# fragments:411
# frame:412
# frames:413
# free:414
# french:415
# from:416
# front:417
# fulfill:418
# full:419
# fully:420
# funding:421
# further:422
# furthermore:423
# general:424
# generally:425
# generated:426
# generation:427
# generative:428
# generic:429
# george:430
# georgetown:431
# german:432
# given:433
# goal:434
# gone:435
# government:436
# governmental:437
# gracefully:438
# gradual:439
# grammar:440
# grammars:441
# grammatical:442
# graph:443
# great:444
# greatly:445
# grounded:446
# grouped:447
# growth:448
# had:449
# half:450
# hand:451
# handling:452
# handwritten:453
# hard:454
# hardly:455
# has:456
# have:457
# he:458
# head:459
# heavily:460
# heuristic:461
# hey:462
# hidden:463
# higher:464
# highly:465
# hours:466
# house:467
# how:468
# however:469
# hpsg:470
# human:471
# humans:472
# hurts:473
# ibm:474
# idea:475
# identical:476
# identification:477
# identified:478
# identify:479
# identifying:480
# if:481
# ignore:482
# image:483
# impaired:484
# implemented:485
# implication:486
# implicit:487
# imply:488
# importance:489
# important:490
# in:491
# inaccurate:492
# include:493
# included:494
# includes:495
# including:496
# increase:497
# increases:498
# increasing:499
# increasingly:500
# indian:501
# indicators:502
# individual:503
# induction:504
# inference:505
# inferior:506
# inflected:507
# inflection:508
# inflectional:509
# information:510
# input:511
# instance:512
# instead:513
# insufficient:514
# integrated:515
# intelligence:516
# intended:517
# intent:518
# intents:519
# interaction:520
# interdisciplinary:521
# intermediate:522
# interpretability:523
# interpretation:524
# intertwined:525
# into:526
# introduced:527
# introduction:528
# involved:529
# involves:530
# involving:531
# ion:532
# is:533
# it:534
# items:535
# its:536
# jabberwacky:537
# japanese:538
# john:539
# joseph:540
# knowledge:541
# known:542
# labelling:543
# lakoff:544
# language:545
# languages:546
# large:547
# largely:548
# larger:549
# late:550
# law:551
# laws:552
# learn:553
# learning:554
# least:555
# led:556
# lehnert:557
# lemma:558
# lesk:559
# less:560
# lessening:561
# letter:562
# letters:563
# level:564
# life:565
# like:566
# likely:567
# limit:568
# limitation:569
# limited:570
# lines:571
# linguistics:572
# list:573
# lithium:574
# little:575
# local:576
# location:577
# logic:578
# logical:579
# long:580
# looked:581
# lookup:582
# low:583
# machine:584
# machinery:585
# made:586
# major:587
# make:588
# makes:589
# making:590
# man:591
# management:592
# manipulate:593
# many:594
# map:595
# margie:596
# mark:597
# marked:598
# marketed:599
# marketing:600
# marking:601
# markov:602
# marks:603
# married:604
# matching:605
# may:606
# meaning:607
# meanings:608
# media:609
# meehan:610
# meitei:611
# member:612
# mental:613
# mentions:614
# merely:615
# metamodel:616
# metaphor:617
# methodology:618
# methods:619
# mid:620
# might:621
# million:622
# mind:623
# mining:624
# misspelled:625
# model:626
# modeling:627
# models:628
# moore:629
# more:630
# morphemes:631
# morphology:632
# most:633
# much:634
# multilingual:635
# multimodal:636
# multiple:637
# must:638
# my:639
# n1950s:640
# n1960s:641
# n1970s:642
# n1980s:643
# n1990s:644
# n2000s:645
# na:646
# name:647
# named:648
# names:649
# natural:650
# nature:651
# nautomatic:652
# nautomatically:653
# nbook:654
# ncognition:655
# ncommon:656
# ncomputer:657
# nconvert:658
# ncoreference:659
# ndespite:660
# ndetermine:661
# ndialogue:662
# ndiscourse:663
# ndistributional:664
# necessary:665
# need:666
# negation:667
# ner:668
# network:669
# networks:670
# neural:671
# new:672
# newspaper:673
# nextract:674
# nfor:675
# nfurther:676
# ngenerate:677
# ngiven:678
# ngrammar:679
# nhigher:680
# nhow:681
# nimplicit:682
# nin:683
# nlemmatization:684
# nlexical:685
# nlg:686
# nlp:687
# nlu:688
# nmachine:689
# nmany:690
# nmethods:691
# nmore:692
# nmorphological:693
# nmt:694
# nnamed:695
# nnatural:696
# nneural:697
# nnot:698
# no:699
# non:700
# nonsensical:701
# noptical:702
# not:703
# notable:704
# notably:705
# notations:706
# noun:707
# nouns:708
# novel:709
# now:710
# nparsing:711
# npart:712
# nproduce:713
# nquestion:714
# nrecognizing:715
# nrelational:716
# nrelationship:717
# nsemantic:718
# nsentence:719
# nsentiment:720
# nseparate:721
# nsince:722
# nsome:723
# nspeech:724
# nstatistical:725
# nstemming:726
# nsymbolic:727
# nsyntactic:728
# nsystems:729
# nterminology:730
# ntext:731
# nthe:732
# nthis:733
# nthough:734
# ntopic:735
# number:736
# nup:737
# nwhat:738
# nwhen:739
# nword:740
# objective:741
# objects:742
# obviating:743
# obvious:744
# occurred:745
# ocr:746
# of:747
# offers:748
# official:749
# often:750
# omitted:751
# on:752
# one:753
# ones:754
# online:755
# only:756
# ontologies:757
# ontology:758
# open:759
# opened:760
# opening:761
# opens:762
# operationalization:763
# opinion:764
# opposite:765
# or:766
# order:767
# organization:768
# organized:769
# orthography:770
# other:771
# others:772
# out:773
# output:774
# over:775
# pam:776
# papers:777
# paradigm:778
# parliament:779
# parry:780
# parse:781
# parses:782
# parsing:783
# part:784
# particular:785
# particularly:786
# parts:787
# patient:788
# pauses:789
# pcfg:790
# people:791
# perhaps:792
# period:793
# periods:794
# person:795
# perspective:796
# phrasebook:797
# piece:798
# pipeline:799
# pipelines:800
# places:801
# plot:802
# plural:803
# polarity:804
# policemen:805
# politics:806
# popular:807
# popularity:808
# pos:809
# possess:810
# possible:811
# possibly:812
# postprocessing:813
# potential:814
# power:815
# practical:816
# predicates:817
# premise:818
# preprocessing:819
# present:820
# presented:821
# primary:822
# printed:823
# pro:824
# probabilistic:825
# problem:826
# problems:827
# procedures:828
# proceedings:829
# process:830
# processes:831
# processing:832
# produce:833
# produced:834
# produces:835
# producing:836
# programmers:837
# programs:838
# progress:839
# prone:840
# pronouns:841
# proper:842
# properly:843
# properties:844
# proposed:845
# provide:846
# provided:847
# provides:848
# psychology:849
# psychotherapist:850
# public:851
# published:852
# punctuation:853
# purposes:854
# qualm:855
# quantitative:856
# question:857
# questions:858
# racter:859
# rather:860
# raw:861
# readable:862
# readily:863
# real:864
# realized:865
# recent:866
# recognition:867
# recognize:868
# recognizing:869
# reduced:870
# reducing:871
# refer:872
# reference:873
# referred:874
# referring:875
# refers:876
# regardless:877
# related:878
# relationship:879
# relationships:880
# relative:881
# relevant:882
# reliable:883
# relied:884
# rely:885
# relying:886
# remain:887
# removing:888
# replaced:889
# report:890
# representation:891
# representations:892
# representing:893
# require:894
# required:895
# requires:896
# requiring:897
# research:898
# researched:899
# resolution:900
# resolve:901
# resource:902
# responding:903
# response:904
# restricted:905
# result:906
# results:907
# return:908
# reviews:909
# revolution:910
# rhetorical:911
# right:912
# rising:913
# road:914
# robust:915
# rogerian:916
# role:917
# roles:918
# room:919
# root:920
# roots:921
# rubric:922
# rule:923
# rules:924
# russian:925
# sam:926
# same:927
# say:928
# schank:929
# science:930
# scientific:931
# scripts:932
# searle:933
# section:934
# see:935
# seem:936
# seen:937
# segment:938
# segmentation:939
# segments:940
# select:941
# semantic:942
# semantics:943
# semi:944
# sense:945
# senses:946
# sensical:947
# sentence:948
# sentences:949
# sentiment:950
# separate:951
# separated:952
# sequence:953
# serve:954
# set:955
# sets:956
# several:957
# shift:958
# shifted:959
# should:960
# showing:961
# shrdlu:962
# signal:963
# significant:964
# similar:965
# simple:966
# simply:967
# simulation:968
# since:969
# single:970
# sixty:971
# slower:972
# small:973
# smt:974
# so:975
# social:976
# soft:977
# software:978
# solutions:979
# solve:980
# solved:981
# solving:982
# some:983
# sometimes:984
# somewhat:985
# sort:986
# sound:987
# sounds:988
# spaces:989
# span:990
# spanish:991
# speaking:992
# specific:993
# specifically:994
# specified:995
# speech:996
# spoken:997
# springer:998
# starting:999
# startlingly:1000
# state:1001
# statement:1002
# statistical:1003
# statistics:1004
# stative:1005
# steady:1006
# stemming:1007
# steps:1008
# still:1009
# stochastic:1010
# stream:1011
# structure:1012
# structured:1013
# structures:1014
# study:1015
# style:1016
# subdivided:1017
# subjective:1018
# substantial:1019
# subtask:1020
# subtasks:1021
# success:1022
# successes:1023
# successful:1024
# successfully:1025
# successive:1026
# such:1027
# summaries:1028
# summarization:1029
# summarized:1030
# summary:1031
# supervised:1032
# supplying:1033
# surprisingly:1034
# symbolic:1035
# syntactic:1036
# syntax:1037
# system:1038
# systems:1039
# table:1040
# tagging:1041
# take:1042
# takes:1043
# talespin:1044
# task:1045
# tasks:1046
# techniques:1047
# ten:1048
# term:1049
# termed:1050
# terminology:1051
# terms:1052
# test:1053
# text:1054
# textual:1055
# thai:1056
# than:1057
# that:1058
# the:1059
# their:1060
# them:1061
# then:1062
# theoretical:1063
# theories:1064
# theory:1065
# there:1066
# these:1067
# they:1068
# things:1069
# this:1070
# those:1071
# thought:1072
# thousands:1073
# three:1074
# through:1075
# thus:1076
# time:1077
# titled:1078
# to:1079
# tokenization:1080
# tonal:1081
# topic:1082
# training:1083
# transform:1084
# transformational:1085
# transformations:1086
# transforming:1087
# translate:1088
# translation:1089
# transparency:1090
# tree:1091
# trees:1092
# trends:1093
# trivial:1094
# true:1095
# turing:1096
# turkish:1097
# turn:1098
# two:1099
# type:1100
# types:1101
# typical:1102
# typically:1103
# unannotated:1104
# underlies:1105
# underpinnings:1106
# understandable:1107
# understanding:1108
# unfamiliar:1109
# union:1110
# units:1111
# unlike:1112
# unmanageable:1113
# unsupervised:1114
# until:1115
# up:1116
# upon:1117
# usages:1118
# use:1119
# used:1120
# useful:1121
# using:1122
# usually:1123
# valued:1124
# variety:1125
# verb:1126
# verbal:1127
# verbalization:1128
# very:1129
# via:1130
# viewed:1131
# visually:1132
# vocabularies:1133
# vocabulary:1134
# vs:1135
# was:1136
# we:1137
# web:1138
# weights:1139
# weizenbaum:1140
# well:1141
# were:1142
# western:1143
# what:1144
# when:1145
# where:1146
# whereas:1147
# whether:1148
# which:1149
# while:1150
# who:1151
# whom:1152
# whose:1153
# why:1154
# wide:1155
# widespread:1156
# wilensky:1157
# will:1158
# with:1159
# within:1160
# without:1161
# word:1162
# wordnet:1163
# words:1164
# work:1165
# worked:1166
# working:1167
# works:1168
# world:1169
# worlds:1170
# would:1171
# write:1172
# writer:1173
# writing:1174
# written:1175
# x80:1176
# x93:1177
# x99s:1178
# x9cbig:1179
# x9cthat:1180
# x9cthe:1181
# x9d:1182
# x9dbig:1183
# x9dimportance:1184
# x9dphysically:1185
# x9dshe:1186
# x9dtomorrow:1187
# xe2:1188
# year:1189
# years:1190
# yes:1191
# you:1192
# your:1193
# zero:1194

# %%
str2 = str(aiExcerpt)[2:]
str2
# Out:
# 'Artificial intelligence (AI), sometimes called machine intelligence, is intelligence demonstrated by machines, unlike the natural intelligence displayed by humans and animals. Leading AI textbooks define the field as the study of "intelligent agents": any device that perceives its environment and takes actions that maximize its chance of successfully achieving its goals.[1] Colloquially, the term "artificial intelligence" is often used to describe machines (or computers) that mimic "cognitive" functions that humans associate with the human mind, such as "learning" and "problem solving".[2] \\nAs machines become increasingly capable, tasks considered to require "intelligence" are often removed from the definition of AI, a phenomenon known as the AI effect.[3] A quip in Tesler\\\'s Theorem says "AI is whatever hasn\\\'t been done yet."[4] For instance, optical character recognition is frequently excluded from things considered to be AI,[5] having become a routine technology.[6] Modern machine capabilities generally classified as AI include successfully understanding human speech,[7] competing at the highest level in strategic game systems (such as chess and Go),[8] autonomously operating cars, intelligent routing in content delivery networks, and military simulations.[9] \\nArtificial intelligence was founded as an academic discipline in 1955, and in the years since has experienced several waves of optimism,[10][11] followed by disappointment and the loss of funding (known as an "AI winter"),[12][13] followed by new approaches, success and renewed funding.[11][14] For most of its history, AI research has been divided into sub-fields that often fail to communicate with each other.[15] These sub-fields are based on technical considerations, such as particular goals (e.g. "robotics" or "machine learning"),[16] the use of particular tools ("logic" or artificial neural networks), or deep philosophical differences.[17][18][19] Sub-fields have also been based on social factors (particular institutions or the work of particular researchers).[15] \\nThe traditional problems (or goals) of AI research include reasoning, knowledge representation, planning, learning, natural language processing, perception and the ability to move and manipulate objects.[16] General intelligence is among the field\\\'s long-term goals.[20] Approaches include statistical methods, computational intelligence, and traditional symbolic AI. Many tools are used in AI, including versions of search and mathematical optimization, artificial neural networks, and methods based on statistics, probability and economics. The AI field draws upon computer science, information engineering, mathematics, psychology, linguistics, philosophy, and many other fields. \\nThe field was founded on the assumption that human intelligence "can be so precisely described that a machine can be made to simulate it".[21] This raises philosophical arguments about the mind and the ethics of creating artificial beings endowed with human-like intelligence. These issues have been explored by myth, fiction and philosophy since antiquity.[22] Some people also consider AI to be a danger to humanity if it progresses unabated.[23][24] Others believe that AI, unlike previous technological revolutions, will create a risk of mass unemployment.[25] \\nIn the twenty-first century, AI techniques have experienced a resurgence following concurrent advances in computer power, large amounts of data, and theoretical understanding; and AI techniques have become an essential part of the technology industry, helping to solve many challenging problems in computer science, software engineering and operations research.\\n\\nThought-capable artificial beings appeared as storytelling devices in antiquity,[27] and have been common in fiction, as in Mary Shelley\\\'s Frankenstein or Karel \\xc4\\x8capek\\\'s R.U.R. (Rossum\\\'s Universal Robots).[28] These characters and their fates raised many of the same issues now discu ...

# %%
text2 = str2.split()
text2
# Out:
# ['Artificial',
#  'intelligence',
#  '(AI),',
#  'sometimes',
#  'called',
#  'machine',
#  'intelligence,',
#  'is',
#  'intelligence',
#  'demonstrated',
#  'by',
#  'machines,',
#  'unlike',
#  'the',
#  'natural',
#  'intelligence',
#  'displayed',
#  'by',
#  'humans',
#  'and',
#  'animals.',
#  'Leading',
#  'AI',
#  'textbooks',
#  'define',
#  'the',
#  'field',
#  'as',
#  'the',
#  'study',
#  'of',
#  '"intelligent',
#  'agents":',
#  'any',
#  'device',
#  'that',
#  'perceives',
#  'its',
#  'environment',
#  'and',
#  'takes',
#  'actions',
#  'that',
#  'maximize',
#  'its',
#  'chance',
#  'of',
#  'successfully',
#  'achieving',
#  'its',
#  'goals.[1]',
#  'Colloquially,',
#  'the',
#  'term',
#  '"artificial',
#  'intelligence"',
#  'is',
#  'often',
#  'used',
#  'to',
#  'describe',
#  'machines',
#  '(or',
#  'computers)',
#  'that',
#  'mimic',
#  '"cognitive"',
#  'functions',
#  'that',
#  'humans',
#  'associate',
#  'with',
#  'the',
#  'human',
#  'mind,',
#  'such',
#  'as',
#  '"learning"',
#  'and',
#  '"problem',
#  'solving".[2]',
#  '\\nAs',
#  'machines',
#  'become',
#  'increasingly',
#  'capable,',
#  'tasks',
#  'considered',
#  'to',
#  'require',
#  '"intelligence"',
#  'are',
#  'often',
#  'removed',
#  'from',
#  'the',
#  'definition',
#  'of',
#  'AI,',
#  'a',
#  'phenomenon',
#  'known',
#  'as',
#  'the',
#  'AI',
#  'effect.[3]',
#  'A',
#  'quip',
#  'in',
#  "Tesler\\'s",
#  'Theorem',
#  'says',
#  '"AI',
#  'is',
#  'whatever',
#  "hasn\\'t",
#  'been',
#  'done',
#  'yet."[4]',
#  'For',
#  'instance,',
#  'optical',
#  'character',
#  'recognition',
#  'is',
#  'frequently',
#  'excluded',
#  'from',
#  'things',
#  'considered',
#  'to',
#  'be',
#  'AI,[5]',
#  'having',
#  'become',
#  'a',
#  'routine',
#  'technology.[6]',
#  'Modern',
#  'machine',
#  'capabilities',
#  'generally',
#  'classified',
#  'as',
#  'AI',
#  'include',
#  'successfully',
#  'understanding',
#  'human',
#  'speech,[7]',
#  'competing',
#  'at',
#  'the',
#  'highest',
#  'level',
#  'in',
#  'strategic',
#  'game',
#  'systems',
#  '(such',
#  'as',
#  'chess',
#  'and',
#  'Go),[8]',
#  'autonomously',
#  'operating',
#  'cars,',
#  'intelligent',
#  'routing',
#  'in',
#  'content',
#  'delivery',
#  'networks,',
#  'and',
#  'military',
#  'simulations.[9]',
#  '\\nArtificial',
#  'intelligence',
#  'was',
#  'founded',
#  'as',
#  'an',
#  'academic',
#  'discipline',
#  'in',
#  '1955,',
#  'and',
#  'in',
#  'the',
#  'years',
#  'since',
#  'has',
#  'experienced',
#  'several',
#  'waves',
#  'of',
#  'optimism,[10][11]',
#  'followed',
#  'by',
#  'disappointment',
#  'and',
#  'the',
#  'loss',
#  'of',
#  'funding',
#  '(known',
#  'as',
#  'an',
#  '"AI',
#  'winter"),[12][13]',
#  'followed',
#  'by',
#  'new',
#  'approaches,',
#  'success',
#  'and',
#  'renewed',
#  'funding.[11][14]',
#  'For',
#  'most',
#  'of',
#  'its',
#  'history,',
#  'AI',
#  'research',
#  'has',
#  'been',
#  'divided',
#  'into',
#  'sub-fields',
#  'that',
#  'often',
#  'fail',
#  'to',
#  'communicate',
#  'with',
#  'each',
#  'other.[15]',
#  'These',
#  'sub-fields',
#  'are',
#  'based',
#  'on',
#  'technical',
#  'considerations,',
#  'such',
#  'as',
#  'particular',
#  'goals',
#  '(e.g.',
#  '"robotics"',
#  'or',
#  '"machine',
#  'learning"),[16]',
#  'the',
#  'use',
#  'of',
#  'particular',
#  'tools',
#  '("logic"',
#  'or',
#  'artificial',
#  'neural',
#  'networks),',
#  'or',
#  'deep',
#  'philosophical',
#  'differences.[17][18][19]',
#  'Sub-fields',
#  'have',
#  'also',
#  'been',
#  'based',
#  'on',
#  'social',
#  'factors',
#  '(particular',
#  'institutions',
#  'or',
#  'the',
#  'work',
#  'of',
#  'particular',
#  'researchers).[15]',
#  '\\nThe',
#  'traditional',
#  'problems',
#  '(or',
#  'goals)',
#  'of',
#  'AI',
#  'research',
#  'include',
#  'reasoning,',
#  'knowledge',
#  'representation,',
#  'planning,',
#  'learning,',
#  'natural',
#  'language',
#  'processing,',
#  'perception',
#  'and',
#  'the',
#  'ability',
#  'to',
#  'move',
#  'and',
#  'manipulate',
#  'objects.[16]',
#  'General',
#  'intelligence',
#  'is',
#  'among',
#  'the',
#  "field\\'s",
#  'long-term',
#  'goals.[20]',
#  'Approaches',
#  'include',
#  'statistical',
#  'methods,',
#  'computational',
#  'intelligence,',
#  'and',
#  'traditional',
#  'symbolic',
#  'AI.',
#  'Many',
#  'tools',
#  'are',
#  'used',
#  'in',
#  'AI,',
#  'including',
#  'versions',
#  'of',
#  'search',
#  'and',
#  'mathematical',
#  'optimization,',
#  'artificial',
#  'neural',
#  'networks,',
#  'and',
#  'methods',
#  'based',
#  'on',
#  'statistics,',
#  'probability',
#  'and',
#  'economics.',
#  'The',
#  'AI',
#  'field',
#  'draws',
#  'upon',
#  'computer',
#  'science,',
#  'information',
#  'engineering,',
#  'mathematics,',
#  'psychology,',
#  'linguistics,',
#  'philosophy,',
#  'and',
#  'many',
#  'other',
#  'fields.',
#  '\\nThe',
#  'field',
#  'was',
#  'founded',
#  'on',
#  'the',
#  'assumption',
#  'that',
#  'human',
#  'intelligence',
#  '"can',
#  'be',
#  'so',
#  'precisely',
#  'described',
#  'that',
#  'a',
#  'machine',
#  'can',
#  'be',
#  'made',
#  'to',
#  'simulate',
#  'it".[21]',
#  'This',
#  'raises',
#  'philosophical',
#  'arguments',
#  'about',
#  'the',
#  'mind',
#  'and',
#  'the',
#  'ethics',
#  'of',
#  'creating',
#  'artificial',
#  'beings',
#  'endowed',
#  'with',
#  'human-like',
#  'intelligence.',
#  'These',
#  'issues',
#  'have',
#  'been',
#  'explored',
#  'by',
#  'myth,',
#  'fiction',
#  'and',
#  'philosophy',
#  'since',
#  'antiquity.[22]',
#  'Some',
#  'people',
#  'also',
#  'consider',
#  'AI',
#  'to',
#  'be',
#  'a',
#  'danger',
#  'to',
#  'humanity',
#  'if',
#  'it',
#  'progresses',
#  'unabated.[23][24]',
#  'Others',
#  'believe',
#  'that',
#  'AI,',
#  'unlike',
#  'previous',
#  'technological',
#  'revolutions,',
#  'will',
#  'create',
#  'a',
#  'risk',
#  'of',
#  'mass',
#  'unemployment.[25]',
#  '\\nIn',
#  'the',
#  'twenty-first',
#  'century,',
#  'AI',
#  'techniques',
#  'have',
#  'experienced',
#  'a',
#  'resurgence',
#  'following',
#  'concurrent',
#  'advances',
#  'in',
#  'computer',
#  'power,',
#  'large',
#  'amounts',
#  'of',
#  'data,',
#  'and',
#  'theoretical',
#  'understanding;',
#  'and',
#  'AI',
#  'techniques',
#  'have',
#  'become',
#  'an',
#  'essential',
#  'part',
#  'of',
#  'the',
#  'technology',
#  'industry,',
#  'helping',
#  'to',
#  'solve',
#  'many',
#  'challenging',
#  'problems',
#  'in',
#  'computer',
#  'science,',
#  'software',
#  'engineering',
#  'and',
#  'operations',
#  'research.\\n\\nThought-capable',
#  'artificial',
#  'beings',
#  'appeared',
#  'as',
#  'storytelling',
#  'devices',
#  'in',
#  'antiquity,[27]',
#  'and',
#  'have',
#  'been',
#  'common',
#  'in',
#  'fiction,',
#  'as',
#  'in',
#  'Mary',
#  "Shelley\\'s",
#  'Frankenstein',
#  'or',
#  'Karel',
#  "\\xc4\\x8capek\\'s",
#  'R.U.R.',
#  "(Rossum\\'s",
#  'Universal',
#  'Robots).[28]',
#  'These',
#  'characters',
#  'and',
#  'their',
#  'fates',
#  'raised',
#  'many',
#  'of',
#  'the',
#  'same',
#  'issues',
#  'now',
#  'discussed',
#  'in',
#  'the',
#  'ethics',
#  'of',
#  'artificial',
#  'intelligence.[22]',
#  '\\nThe',
#  'study',
#  'of',
#  'mechanical',
#  'or',
#  '"formal"',
#  'reasoning',
#  'began',
#  'with',
#  'philosophers',
#  'and',
#  'mathematicians',
#  'in',
#  'antiquity.',
#  'The',
#  'study',
#  'of',
#  'mathematical',
#  'logic',
#  'led',
#  'directly',
#  'to',
#  'Alan',
#  "Turing\\'s",
#  'theory',
#  'of',
#  'computation,',
#  'which',
#  'suggested',
#  'that',
#  'a',
#  'machine,',
#  'by',
#  'shuffling',
#  'symbols',
#  'as',
#  'simple',
#  'as',
#  '"0"',
#  'and',
#  '"1",',
#  'could',
#  'simulate',
#  'any',
#  'conceivable',
#  'act',
#  'of',
#  'mathematical',
#  'deduction.',
#  'This',
#  'insight,',
#  'that',
#  'digital',
#  'computers',
#  'can',
#  'simulate',
#  'any',
#  'process',
#  'of',
#  'formal',
#  'reasoning,',
#  'is',
#  'known',
#  'as',
#  'the',
#  'Church\\xe2\\x80\\x93Turing',
#  'thesis.[29]',
#  'Along',
#  'with',
#  'concurrent',
#  'discoveries',
#  'in',
#  'neurobiology,',
#  'information',
#  'theory',
#  'and',
#  'cybernetics,',
#  'this',
#  'led',
#  'researchers',
#  'to',
#  'consider',
#  'the',
#  'possibility',
#  'of',
#  'building',
#  'an',
#  'electronic',
#  'brain.',
#  'Turing',
#  'proposed',
#  'changing',
#  'the',
#  'question',
#  'from',
#  'whether',
#  'a',
#  'machine',
#  'was',
#  'intelligent,',
#  'to',
#  '"whether',
#  'or',
#  'not',
#  'it',
#  'is',
#  'possible',
#  'for',
#  'machinery',
#  'to',
#  'show',
#  'intelligent',
#  'behaviour".[30]',
#  'The',
#  'first',
#  'work',
#  'that',
#  'is',
#  'now',
#  'generally',
#  'recognized',
#  'as',
#  'AI',
#  'was',
#  'McCullouch',
#  'and',
#  "Pitts\\'",
#  '1943',
#  'formal',
#  'design',
#  'for',
#  'Turing-complete',
#  '"artificial',
#  'neurons".[31]',
#  '\\nThe',
#  'field',
#  'of',
#  'AI',
#  'research',
#  'was',
#  'born',
#  'at',
#  'a',
#  'workshop',
#  'at',
#  'Dartmouth',
#  'College',
#  'in',
#  '1956,[32]',
#  'where',
#  'the',
#  'term',
#  '"Artificial',
#  'Intelligence"',
#  'was',
#  'coined',
#  'by',
#  'John',
#  'McCarthy',
#  'to',
#  'distinguish',
#  'the',
#  'field',
#  'from',
#  'cybernetics',
#  'and',
#  'escape',
#  'the',
#  'influence',
#  'of',
#  'the',
#  'cyberneticist',
#  'Norbert',
#  'Wiener.[33]',
#  'Attendees',
#  'Allen',
#  'Newell',
#  '(CMU),',
#  'Herbert',
#  'Simon',
#  '(CMU),',
#  'John',
#  'McCarthy',
#  '(MIT),',
#  'Marvin',
#  'Minsky',
#  '(MIT)',
#  'and',
#  'Arthur',
#  'Samuel',
#  '(IBM)',
#  'became',
#  'the',
#  'founders',
#  'and',
#  'leaders',
#  'of',
#  'AI',
#  'research.[34]',
#  'They',
#  'and',
#  'their',
#  'students',
#  'produced',
#  'programs',
#  'that',
#  'the',
#  'press',
#  'described',
#  'as',
#  '"astonishing":[35]',
#  'computers',
#  'were',
#  'learning',
#  'checkers',
#  'strategies',
#  '(c.',
#  '1954)[36]',
#  '(and',
#  'by',
#  '1959',
#  'were',
#  'reportedly',
#  'playing',
#  'better',
#  'than',
#  'the',
#  'average',
#  'human),[37]',
#  'solving',
#  'word',
#  'problems',
#  'in',
#  'algebra,',
#  'proving',
#  'logical',
#  'theorems',
#  '(Logic',
#  'Theorist,',
#  'first',
#  'run',
#  'c.',
#  '1956)',
#  'and',
#  'speaking',
#  'English.[38]',
#  'By',
#  'the',
#  'middle',
#  'of',
#  'the',
#  '1960s,',
#  'research',
#  'in',
#  'the',
#  'U.S.',
#  'was',
#  'heavily',
#  'funded',
#  'by',
#  'the',
#  'Department',
#  'of',
#  'Defense[39]',
#  'and',
#  'laboratories',
#  'had',
#  'been',
#  'established',
#  'around',
#  'the',
#  'world.[40]',
#  "AI\\'s",
#  'founders',
#  'were',
#  'optimistic',
#  'about',
#  'the',
#  'future:',
#  'Herbert',
#  'Simon',
#  'predicted,',
#  '"machines',
#  'will',
#  'be',
#  'capable,',
#  'within',
#  'twenty',
#  'years,',
#  'of',
#  'doing',
#  'any',
#  'work',
#  'a',
#  'man',
#  'can',
#  'do".',
#  'Marvin',
#  'Minsky',
#  'agreed,',
#  'writing,',
#  '"within',
#  'a',
#  'generation\\xc2\\xa0...',
#  'the',
#  'problem',
#  'of',
#  'creating',
#  "\\'artificial",
#  "intelligence\\'",
#  'will',
#  'substantially',
#  'be',
#  'solved".[10]',
#  '\\nThey',
#  'failed',
#  'to',
#  'recognize',
#  'the',
#  'difficulty',
#  'of',
#  'some',
#  'of',
#  'the',
#  'remaining',
#  'tasks.',
#  'Progress',
#  'slowed',
#  'and',
#  'in',
#  '1974,',
#  'in',
#  'response',
#  'to',
#  'the',
#  'criticism',
#  'of',
#  'Sir',
#  'James',
#  'Lighthill[41]',
#  'and',
#  'ongoing',
#  'pressure',
#  'from',
#  'the',
#  'US',
#  'Congress',
#  'to',
#  'fund',
#  'more',
#  'productive',
#  'projects,',
#  'both',
#  'the',
#  'U.S.',
#  'and',
#  'British',
#  'governments',
#  'cut',
#  'off',
#  'exploratory',
#  'research',
#  'in',
#  'AI.',
#  'The',
#  'next',
#  'few',
#  'years',
#  'would',
#  'later',
#  'be',
#  'called',
#  'an',
#  '"AI',
#  'winter",[12]',
#  'a',
#  'period',
#  'when',
#  'obtaining',
#  'funding',
#  'for',
#  'AI',
#  'projects',
#  'was',
#  'difficult.',
#  '\\nIn',
#  'the',
#  'early',
#  '1980s,',
#  'AI',
#  'research',
#  'was',
#  'revived',
#  'by',
#  'the',
#  'commercial',
#  'success',
#  'of',
#  'expert',
#  'systems,[42]',
#  'a',
#  'form',
#  'of',
#  'AI',
#  'program',
#  'that',
#  'simulated',
#  'the',
#  'knowledge',
#  'and',
#  'analytical',
#  'skills',
#  'of',
#  'human',
#  'experts.',
#  'By',
#  '1985,',
#  'the',
#  'market',
#  'for',
#  'AI',
#  'had',
#  'reached',
#  'over',
#  'a',
#  'billion',
#  'dollars.',
#  'At',
#  'the',
#  'same',
#  'time,',
#  "Japan\\'s",
#  'fifth',
#  'generation',
#  'computer',
#  'project',
#  'inspired',
#  'the',
#  'U.S',
#  'and',
#  'British',
#  'governments',
#  'to',
#  'restore',
#  'funding',
#  'for',
#  'academic',
#  'research.[11]',
#  'However,',
#  'beginning',
#  'with',
#  'the',
#  'collapse',
#  ...]

# %%
z = vect.transform(text2).toarray()
count=0
print(len(z))
# print(z)
# z0=z[0]
# print(z0)
# for i in range(len(z0)):
#     if(z0[i]>0):
#         print(i)
