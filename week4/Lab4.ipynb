# %%
#TASK 2: SIMPLE TEXT CLASSIFICATION
def gender_features(word):
    return {'last_letter':word[-1]}

# %%
gender_features('Obama')
# Out:
# {'last_letter': 'a'}

# %%
from nltk.corpus import names
names.words()
# Out:
# ['Abagael',
#  'Abagail',
#  'Abbe',
#  'Abbey',
#  'Abbi',
#  'Abbie',
#  'Abby',
#  'Abigael',
#  'Abigail',
#  'Abigale',
#  'Abra',
#  'Acacia',
#  'Ada',
#  'Adah',
#  'Adaline',
#  'Adara',
#  'Addie',
#  'Addis',
#  'Adel',
#  'Adela',
#  'Adelaide',
#  'Adele',
#  'Adelice',
#  'Adelina',
#  'Adelind',
#  'Adeline',
#  'Adella',
#  'Adelle',
#  'Adena',
#  'Adey',
#  'Adi',
#  'Adiana',
#  'Adina',
#  'Adora',
#  'Adore',
#  'Adoree',
#  'Adorne',
#  'Adrea',
#  'Adria',
#  'Adriaens',
#  'Adrian',
#  'Adriana',
#  'Adriane',
#  'Adrianna',
#  'Adrianne',
#  'Adrien',
#  'Adriena',
#  'Adrienne',
#  'Aeriel',
#  'Aeriela',
#  'Aeriell',
#  'Ag',
#  'Agace',
#  'Agata',
#  'Agatha',
#  'Agathe',
#  'Aggi',
#  'Aggie',
#  'Aggy',
#  'Agna',
#  'Agnella',
#  'Agnes',
#  'Agnese',
#  'Agnesse',
#  'Agneta',
#  'Agnola',
#  'Agretha',
#  'Aida',
#  'Aidan',
#  'Aigneis',
#  'Aila',
#  'Aile',
#  'Ailee',
#  'Aileen',
#  'Ailene',
#  'Ailey',
#  'Aili',
#  'Ailina',
#  'Ailyn',
# ...

# %%
l = names.words()
len(l)
# Out:
# 7944

# %%
labeled_names = ([(name,'male') for name in names.words('male.txt')] + [(name, 'female')  for name in names.words('female.txt')])
labeled_names
# Out:
# [('Aamir', 'male'),
#  ('Aaron', 'male'),
#  ('Abbey', 'male'),
#  ('Abbie', 'male'),
#  ('Abbot', 'male'),
#  ('Abbott', 'male'),
#  ('Abby', 'male'),
#  ('Abdel', 'male'),
#  ('Abdul', 'male'),
#  ('Abdulkarim', 'male'),
#  ('Abdullah', 'male'),
#  ('Abe', 'male'),
#  ('Abel', 'male'),
#  ('Abelard', 'male'),
#  ('Abner', 'male'),
#  ('Abraham', 'male'),
#  ('Abram', 'male'),
#  ('Ace', 'male'),
#  ('Adair', 'male'),
#  ('Adam', 'male'),
#  ('Adams', 'male'),
#  ('Addie', 'male'),
#  ('Adger', 'male'),
#  ('Aditya', 'male'),
#  ('Adlai', 'male'),
#  ('Adnan', 'male'),
#  ('Adolf', 'male'),
#  ('Adolfo', 'male'),
#  ('Adolph', 'male'),
#  ('Adolphe', 'male'),
#  ('Adolpho', 'male'),
#  ('Adolphus', 'male'),
#  ('Adrian', 'male'),
#  ('Adrick', 'male'),
#  ('Adrien', 'male'),
#  ('Agamemnon', 'male'),
#  ('Aguinaldo', 'male'),
#  ('Aguste', 'male'),
#  ('Agustin', 'male'),
#  ('Aharon', 'male'),
#  ('Ahmad', 'male'),
#  ('Ahmed', 'male'),
#  ('Ahmet', 'male'),
#  ('Ajai', 'male'),
# ...

# %%
import random
random.shuffle(labeled_names)

# %%
featuresets = [(gender_features(n),gender) for (n,gender) in labeled_names]
featuresets
# Out:
# [({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'g'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'v'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
# ...

# %%
train_set, test_set = featuresets[:5000], featuresets[5000:]

# %%
import nltk
classifier = nltk.NaiveBayesClassifier.train(train_set)
classifier

# %%
classifier.classify(gender_features('David'))
# Out:
# 'male'

# %%
classifier.classify(gender_features('Aditya'))
# Out:
# 'female'

# %%
classifier.classify(gender_features('Gunjan'))
# Out:
# 'male'

# %%
print(nltk.classify.accuracy(classifier,test_set))
# Out:
# 0.7608695652173914

# %%
# Opinion drawn: this way of classifying is flawed
# Observation: even if I add my name to the corpus, 
# it will show wrong result 
# Improvement: check if the name entered is available in the corpus, 
# if so, just return the corresponding gender
# else, use the 'gender_features' function

# %%
#Task 3 COUNT VECTORIZER
from sklearn.feature_extraction.text import CountVectorizer

# %%
vect = CountVectorizer(binary=True)
corpus = ["Tessaract is good optical character recognition engine  ", "optical character recognition is significant "]

# %%
vect.fit(corpus)
# Out:
# CountVectorizer(analyzer='word', binary=True, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 1), preprocessor=None, stop_words=None,
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
vocab = vect.vocabulary_
vocab
# Out:
# {'tessaract': 7,
#  'is': 3,
#  'good': 2,
#  'optical': 4,
#  'character': 0,
#  'recognition': 5,
#  'engine': 1,
#  'significant': 6}

# %%
for key in sorted(vocab.keys()):
    print("{}:{}".format(key,vocab[key]))
# Out:
# character:0
# engine:1
# good:2
# is:3
# optical:4
# recognition:5
# significant:6
# tessaract:7

# %%
print(vect.transform(["This is a good optical illusion"]).toarray())
# Out:
# [[0 0 1 1 1 0 0 0]]

# %%
# 28th October (Individual Activity)
# Task 1
#take doc
#stem
#vectorize
#find similarity between both

# %%
# Task 2
#take doc
#don't stem
#vectorize
#find similarty

#does google stem?

# %%
#Group Activity
